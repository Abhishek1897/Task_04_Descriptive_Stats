# %%
import pandas as pd

DATA_FILE = "2024_tw_posts_president_scored_anon.csv"

# Load data
df = pd.read_csv(DATA_FILE)

# Detect column types
numeric_cols = df.select_dtypes(include="number").columns.tolist()
non_numeric_cols = df.select_dtypes(exclude="number").columns.tolist()

# === Structured Summary Printer ===
def summarize(df_part, label="Summary"):
    print(f"\n{'=' * 60}")
    print(label)
    print(f"{'=' * 60}")

    if df_part.empty:
        print("No data available.\n")
        return

    if numeric_cols:
        print("\n📊 Numeric Columns:")
        desc = df_part[numeric_cols].describe().transpose()
        print(desc.round(2))

    print("\n📝 Non-Numeric Columns:")
    for col in non_numeric_cols:
        vc = df_part[col].value_counts(dropna=True)
        if not vc.empty:
            most_common = vc.index[0]
            most_count = vc.iloc[0]
            print(f"- {col}:")
            print(f"    Unique values  : {df_part[col].nunique(dropna=True)}")
            print(f"    Most frequent  : '{most_common}' ({most_count} times)")

# === Overall summary ===
summarize(df, "🌐 Overall Twitter Posts Summary")

# === Grouped by 'id' (first 5)
for tweet_id, group in list(df.groupby("id"))[:5]:
    summarize(group, f"📁 Group: id = {tweet_id}")

# === Grouped by 'id + quoteId' (Top 10 frequent combos)
top_combos = df.groupby(["id", "quoteId"]).size().sort_values(ascending=False).head(10).index
for tid, qid in top_combos:
    group = df[(df["id"] == tid) & (df["quoteId"] == qid)]
    summarize(group, f"🔗 Group: id = {tid}, quoteId = {qid}")
# Out:
# ============================================================
# 🌐 Overall Twitter Posts Summary
# ============================================================
#
# 📊 Numeric Columns:
#                                              count          mean  \
# retweetCount                               27304.0  1.322060e+03
# replyCount                                 27304.0  1.063790e+03
# likeCount                                  27304.0  6.913690e+03
# quoteCount                                 27304.0  1.280800e+02
# viewCount                                  27304.0  5.070847e+05
# bookmarkCount                              27304.0  1.362100e+02
# quoteId                                     3287.0  1.764298e+18
# inReplyToId                                 3345.0  1.758286e+18
# election_integrity_Truth_illuminating      26034.0  4.000000e-02
# advocacy_msg_type_illuminating             26034.0  5.600000e-01
# issue_msg_type_illuminating                26034.0  5.100000e-01
# attack_msg_type_illuminating               26034.0  3.100000e-01
# image_msg_type_illuminating                26034.0  2.300000e-01
# cta_msg_type_illuminating                  26034.0  1.100000e-01
# engagement_cta_subtype_illuminating        26034.0  7.000000e-02
# fundraising_cta_subtype_illuminating       26034.0  1.000000e-02
# voting_cta_subtype_illuminating            26034.0  2.000000e-02
# covid_topic_illuminating                   26034.0  1.000000e-02
# economy_topic_illuminating                 26034.0  1.600000e-01
# education_topic_illuminating               26034.0  2.000000e-02
# environment_topic_illuminating             26034.0  3.000000e-02
# foreign_policy_topic_illuminating          26034.0  4.000000e-02
# governance_topic_illuminating              26034.0  2.000000e-02
# health_topic_illuminating                  26034.0  6.000000e-02
# immigration_topic_illuminating             26034.0  7.000000e-02
# lgbtq_issues_topic_illuminating            26034.0  0.000000e+00
# military_topic_illuminating                26034.0  1.000000e-02
# race_and_ethnicity_topic_illuminating      26034.0  2.000000e-02
# safety_topic_illuminating                  26034.0  4.000000e-02
# social_and_cultural_topic_illuminating     26034.0  5.000000e-02
# technology_and_privacy_topic_illuminating  26034.0  0.000000e+00
# womens_issue_topic_illuminating            26034.0  2.000000e-02
# incivility_illuminating                    26034.0  1.800000e-01
# scam_illuminating                          26034.0  1.000000e-02
# freefair_illuminating                      27304.0  0.000000e+00
# fraud_illuminating                         27304.0  0.000000e+00
#
#                                                     std           min  \
# retweetCount                               3.405000e+03  0.000000e+00
# replyCount                                 3.174980e+03  0.000000e+00
# likeCount                                  2.159031e+04  0.000000e+00
# quoteCount                                 1.131530e+03  0.000000e+00
# viewCount                                  3.212174e+06  5.000000e+00
# bookmarkCount                              7.125800e+02  0.000000e+00
# quoteId                                    6.894687e+16  7.912639e+17
# inReplyToId                                4.361197e+16  1.240067e+18
# election_integrity_Truth_illuminating      1.900000e-01  0.000000e+00
# advocacy_msg_type_illuminating             5.000000e-01  0.000000e+00
# issue_msg_type_illuminating                5.000000e-01  0.000000e+00
# attack_msg_type_illuminating               4.600000e-01  0.000000e+00
# image_msg_type_illuminating                4.200000e-01  0.000000e+00
# cta_msg_type_illuminating                  3.100000e-01  0.000000e+00
# engagement_cta_subtype_illuminating        2.500000e-01  0.000000e+00
# fundraising_cta_subtype_illuminating       9.000000e-02  0.000000e+00
# voting_cta_subtype_illuminating            1.300000e-01  0.000000e+00
# covid_topic_illuminating                   9.000000e-02  0.000000e+00
# economy_topic_illuminating                 3.700000e-01  0.000000e+00
# education_topic_illuminating               1.300000e-01  0.000000e+00
# environment_topic_illuminating             1.700000e-01  0.000000e+00
# foreign_policy_topic_illuminating          2.000000e-01  0.000000e+00
# governance_topic_illuminating              1.500000e-01  0.000000e+00
# health_topic_illuminating                  2.300000e-01  0.000000e+00
# immigration_topic_illuminating             2.500000e-01  0.000000e+00
# lgbtq_issues_topic_illuminating            6.000000e-02  0.000000e+00
# military_topic_illuminating                1.000000e-01  0.000000e+00
# race_and_ethnicity_topic_illuminating      1.200000e-01  0.000000e+00
# safety_topic_illuminating                  1.900000e-01  0.000000e+00
# social_and_cultural_topic_illuminating     2.200000e-01  0.000000e+00
# technology_and_privacy_topic_illuminating  5.000000e-02  0.000000e+00
# womens_issue_topic_illuminating            1.500000e-01  0.000000e+00
# incivility_illuminating                    3.800000e-01  0.000000e+00
# scam_illuminating                          1.100000e-01  0.000000e+00
# freefair_illuminating                      4.000000e-02  0.000000e+00
# fraud_illuminating                         5.000000e-02  0.000000e+00
#
#                                                     25%           50%  \
# retweetCount                               8.400000e+01  3.330000e+02
# replyCount                                 4.300000e+01  1.310000e+02
# likeCount                                  3.930000e+02  1.406000e+03
# quoteCount                                 5.000000e+00  1.700000e+01
# viewCount                                  2.785275e+04  7.094200e+04
# bookmarkCount                              4.000000e+00  2.100000e+01
# quoteId                                    1.726459e+18  1.756496e+18
# inReplyToId                                1.726801e+18  1.746641e+18
# election_integrity_Truth_illuminating      0.000000e+00  0.000000e+00
# advocacy_msg_type_illuminating             0.000000e+00  1.000000e+00
# issue_msg_type_illuminating                0.000000e+00  1.000000e+00
# attack_msg_type_illuminating               0.000000e+00  0.000000e+00
# image_msg_type_illuminating                0.000000e+00  0.000000e+00
# cta_msg_type_illuminating                  0.000000e+00  0.000000e+00
# engagement_cta_subtype_illuminating        0.000000e+00  0.000000e+00
# fundraising_cta_subtype_illuminating       0.000000e+00  0.000000e+00
# voting_cta_subtype_illuminating            0.000000e+00  0.000000e+00
# covid_topic_illuminating                   0.000000e+00  0.000000e+00
# economy_topic_illuminating                 0.000000e+00  0.000000e+00
# education_topic_illuminating               0.000000e+00  0.000000e+00
# environment_topic_illuminating             0.000000e+00  0.000000e+00
# foreign_policy_topic_illuminating          0.000000e+00  0.000000e+00
# governance_topic_illuminating              0.000000e+00  0.000000e+00
# health_topic_illuminating                  0.000000e+00  0.000000e+00
# immigration_topic_illuminating             0.000000e+00  0.000000e+00
# lgbtq_issues_topic_illuminating            0.000000e+00  0.000000e+00
# military_topic_illuminating                0.000000e+00  0.000000e+00
# race_and_ethnicity_topic_illuminating      0.000000e+00  0.000000e+00
# safety_topic_illuminating                  0.000000e+00  0.000000e+00
# social_and_cultural_topic_illuminating     0.000000e+00  0.000000e+00
# technology_and_privacy_topic_illuminating  0.000000e+00  0.000000e+00
# womens_issue_topic_illuminating            0.000000e+00  0.000000e+00
# incivility_illuminating                    0.000000e+00  0.000000e+00
# scam_illuminating                          0.000000e+00  0.000000e+00
# freefair_illuminating                      0.000000e+00  0.000000e+00
# fraud_illuminating                         0.000000e+00  0.000000e+00
#
#                                                     75%           max
# retweetCount                               1.071000e+03  1.446150e+05
# replyCount                                 5.012500e+02  1.212700e+05
# likeCount                                  5.010000e+03  9.152210e+05
# quoteCount                                 6.900000e+01  1.233200e+05
# viewCount                                  3.036630e+05  3.335028e+08
# bookmarkCount                              7.600000e+01  4.269300e+04
# quoteId                                    1.816599e+18  1.853576e+18
# inReplyToId                                1.789226e+18  1.853531e+18
# election_integrity_Truth_illuminating      0.000000e+00  1.000000e+00
# advocacy_msg_type_illuminating             1.000000e+00  1.000000e+00
# issue_msg_type_illuminating                1.000000e+00  1.000000e+00
# attack_msg_type_illuminating               1.000000e+00  1.000000e+00
# image_msg_type_illuminating                0.000000e+00  1.000000e+00
# cta_msg_type_illuminating                  0.000000e+00  1.000000e+00
# engagement_cta_subtype_illuminating        0.000000e+00  1.000000e+00
# fundraising_cta_subtype_illuminating       0.000000e+00  1.000000e+00
# voting_cta_subtype_illuminating            0.000000e+00  1.000000e+00
# covid_topic_illuminating                   0.000000e+00  1.000000e+00
# economy_topic_illuminating                 0.000000e+00  1.000000e+00
# education_topic_illuminating               0.000000e+00  1.000000e+00
# environment_topic_illuminating             0.000000e+00  1.000000e+00
# foreign_policy_topic_illuminating          0.000000e+00  1.000000e+00
# governance_topic_illuminating              0.000000e+00  1.000000e+00
# health_topic_illuminating                  0.000000e+00  1.000000e+00
# immigration_topic_illuminating             0.000000e+00  1.000000e+00
# lgbtq_issues_topic_illuminating            0.000000e+00  1.000000e+00
# military_topic_illuminating                0.000000e+00  1.000000e+00
# race_and_ethnicity_topic_illuminating      0.000000e+00  1.000000e+00
# safety_topic_illuminating                  0.000000e+00  1.000000e+00
# social_and_cultural_topic_illuminating     0.000000e+00  1.000000e+00
# technology_and_privacy_topic_illuminating  0.000000e+00  1.000000e+00
# womens_issue_topic_illuminating            0.000000e+00  1.000000e+00
# incivility_illuminating                    0.000000e+00  1.000000e+00
# scam_illuminating                          0.000000e+00  1.000000e+00
# freefair_illuminating                      0.000000e+00  1.000000e+00
# fraud_illuminating                         0.000000e+00  1.000000e+00
#
# 📝 Non-Numeric Columns:
# - id:
#     Unique values  : 27304
#     Most frequent  : 'cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d' (1 times)
# - url:
#     Unique values  : 27304
#     Most frequent  : 'f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937' (1 times)
# - source:
#     Unique values  : 14
#     Most frequent  : 'Twitter Web App' (14930 times)
# - createdAt:
#     Unique values  : 27014
#     Most frequent  : '2023-10-06 04:55:21' (4 times)
# - lang:
#     Unique values  : 12
#     Most frequent  : 'en' (27281 times)
# - isReply:
#     Unique values  : 2
#     Most frequent  : 'False' (23930 times)
# - isRetweet:
#     Unique values  : 1
#     Most frequent  : 'False' (27304 times)
# - isQuote:
#     Unique values  : 2
#     Most frequent  : 'False' (24064 times)
# - isConversationControlled:
#     Unique values  : 2
#     Most frequent  : 'False' (27296 times)
# - month_year:
#     Unique values  : 15
#     Most frequent  : '2024-10' (3586 times)
# - illuminating_scored_message:
#     Unique values  : 27136
#     Most frequent  : '36cb7d55fcf85362ca03f624c2f574f1f55f89db559b17da084df6e643afe5cd' (21 times)
#
# ============================================================
# 📁 Group: id = 0000635d0c9e7bdf89dfc13811d080dbffac54894594354aa0876b3c12d59aeb
# ============================================================
#
# 📊 Numeric Columns:
#                                            count     mean  std      min  \
# retweetCount                                 1.0     44.0  NaN     44.0
# replyCount                                   1.0    171.0  NaN    171.0
# likeCount                                    1.0    229.0  NaN    229.0
# quoteCount                                   1.0      6.0  NaN      6.0
# viewCount                                    1.0  48756.0  NaN  48756.0
# bookmarkCount                                1.0      3.0  NaN      3.0
# quoteId                                      0.0      NaN  NaN      NaN
# inReplyToId                                  0.0      NaN  NaN      NaN
# election_integrity_Truth_illuminating        1.0      0.0  NaN      0.0
# advocacy_msg_type_illuminating               1.0      1.0  NaN      1.0
# issue_msg_type_illuminating                  1.0      1.0  NaN      1.0
# attack_msg_type_illuminating                 1.0      1.0  NaN      1.0
# image_msg_type_illuminating                  1.0      0.0  NaN      0.0
# cta_msg_type_illuminating                    1.0      0.0  NaN      0.0
# engagement_cta_subtype_illuminating          1.0      0.0  NaN      0.0
# fundraising_cta_subtype_illuminating         1.0      0.0  NaN      0.0
# voting_cta_subtype_illuminating              1.0      0.0  NaN      0.0
# covid_topic_illuminating                     1.0      0.0  NaN      0.0
# economy_topic_illuminating                   1.0      0.0  NaN      0.0
# education_topic_illuminating                 1.0      0.0  NaN      0.0
# environment_topic_illuminating               1.0      0.0  NaN      0.0
# foreign_policy_topic_illuminating            1.0      1.0  NaN      1.0
# governance_topic_illuminating                1.0      0.0  NaN      0.0
# health_topic_illuminating                    1.0      0.0  NaN      0.0
# immigration_topic_illuminating               1.0      0.0  NaN      0.0
# lgbtq_issues_topic_illuminating              1.0      0.0  NaN      0.0
# military_topic_illuminating                  1.0      0.0  NaN      0.0
# race_and_ethnicity_topic_illuminating        1.0      0.0  NaN      0.0
# safety_topic_illuminating                    1.0      0.0  NaN      0.0
# social_and_cultural_topic_illuminating       1.0      0.0  NaN      0.0
# technology_and_privacy_topic_illuminating    1.0      0.0  NaN      0.0
# womens_issue_topic_illuminating              1.0      0.0  NaN      0.0
# incivility_illuminating                      1.0      1.0  NaN      1.0
# scam_illuminating                            1.0      0.0  NaN      0.0
# freefair_illuminating                        1.0      0.0  NaN      0.0
# fraud_illuminating                           1.0      0.0  NaN      0.0
#
#                                                25%      50%      75%      max
# retweetCount                                  44.0     44.0     44.0     44.0
# replyCount                                   171.0    171.0    171.0    171.0
# likeCount                                    229.0    229.0    229.0    229.0
# quoteCount                                     6.0      6.0      6.0      6.0
# viewCount                                  48756.0  48756.0  48756.0  48756.0
# bookmarkCount                                  3.0      3.0      3.0      3.0
# quoteId                                        NaN      NaN      NaN      NaN
# inReplyToId                                    NaN      NaN      NaN      NaN
# election_integrity_Truth_illuminating          0.0      0.0      0.0      0.0
# advocacy_msg_type_illuminating                 1.0      1.0      1.0      1.0
# issue_msg_type_illuminating                    1.0      1.0      1.0      1.0
# attack_msg_type_illuminating                   1.0      1.0      1.0      1.0
# image_msg_type_illuminating                    0.0      0.0      0.0      0.0
# cta_msg_type_illuminating                      0.0      0.0      0.0      0.0
# engagement_cta_subtype_illuminating            0.0      0.0      0.0      0.0
# fundraising_cta_subtype_illuminating           0.0      0.0      0.0      0.0
# voting_cta_subtype_illuminating                0.0      0.0      0.0      0.0
# covid_topic_illuminating                       0.0      0.0      0.0      0.0
# economy_topic_illuminating                     0.0      0.0      0.0      0.0
# education_topic_illuminating                   0.0      0.0      0.0      0.0
# environment_topic_illuminating                 0.0      0.0      0.0      0.0
# foreign_policy_topic_illuminating              1.0      1.0      1.0      1.0
# governance_topic_illuminating                  0.0      0.0      0.0      0.0
# health_topic_illuminating                      0.0      0.0      0.0      0.0
# immigration_topic_illuminating                 0.0      0.0      0.0      0.0
# lgbtq_issues_topic_illuminating                0.0      0.0      0.0      0.0
# military_topic_illuminating                    0.0      0.0      0.0      0.0
# race_and_ethnicity_topic_illuminating          0.0      0.0      0.0      0.0
# safety_topic_illuminating                      0.0      0.0      0.0      0.0
# social_and_cultural_topic_illuminating         0.0      0.0      0.0      0.0
# technology_and_privacy_topic_illuminating      0.0      0.0      0.0      0.0
# womens_issue_topic_illuminating                0.0      0.0      0.0      0.0
# incivility_illuminating                        1.0      1.0      1.0      1.0
# scam_illuminating                              0.0      0.0      0.0      0.0
# freefair_illuminating                          0.0      0.0      0.0      0.0
# fraud_illuminating                             0.0      0.0      0.0      0.0
#
# 📝 Non-Numeric Columns:
# - id:
#     Unique values  : 1
#     Most frequent  : '0000635d0c9e7bdf89dfc13811d080dbffac54894594354aa0876b3c12d59aeb' (1 times)
# - url:
#     Unique values  : 1
#     Most frequent  : '9544b9597374440af0f283fa174c2c3ed0564d611003fecc99b52ba9ff4d3c57' (1 times)
# - source:
#     Unique values  : 1
#     Most frequent  : 'Sprout Social' (1 times)
# - createdAt:
#     Unique values  : 1
#     Most frequent  : '2023-10-17 14:38:46' (1 times)
# - lang:
#     Unique values  : 1
#     Most frequent  : 'en' (1 times)
# - isReply:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isRetweet:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isQuote:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isConversationControlled:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - month_year:
#     Unique values  : 1
#     Most frequent  : '2023-10' (1 times)
# - illuminating_scored_message:
#     Unique values  : 1
#     Most frequent  : '03ed31e29ad72def8de00632e367804bb9a6e45148c13f1062f74099d2482e52' (1 times)
#
# ============================================================
# 📁 Group: id = 00008766c5fc0cb57b4d76792f8f1cea9ead8cf29217dd5bc2e3bafb9ba9fab9
# ============================================================
#
# 📊 Numeric Columns:
#                                            count     mean  std      min  \
# retweetCount                                 1.0    101.0  NaN    101.0
# replyCount                                   1.0     26.0  NaN     26.0
# likeCount                                    1.0    290.0  NaN    290.0
# quoteCount                                   1.0     13.0  NaN     13.0
# viewCount                                    1.0  24795.0  NaN  24795.0
# bookmarkCount                                1.0      5.0  NaN      5.0
# quoteId                                      0.0      NaN  NaN      NaN
# inReplyToId                                  0.0      NaN  NaN      NaN
# election_integrity_Truth_illuminating        0.0      NaN  NaN      NaN
# advocacy_msg_type_illuminating               0.0      NaN  NaN      NaN
# issue_msg_type_illuminating                  0.0      NaN  NaN      NaN
# attack_msg_type_illuminating                 0.0      NaN  NaN      NaN
# image_msg_type_illuminating                  0.0      NaN  NaN      NaN
# cta_msg_type_illuminating                    0.0      NaN  NaN      NaN
# engagement_cta_subtype_illuminating          0.0      NaN  NaN      NaN
# fundraising_cta_subtype_illuminating         0.0      NaN  NaN      NaN
# voting_cta_subtype_illuminating              0.0      NaN  NaN      NaN
# covid_topic_illuminating                     0.0      NaN  NaN      NaN
# economy_topic_illuminating                   0.0      NaN  NaN      NaN
# education_topic_illuminating                 0.0      NaN  NaN      NaN
# environment_topic_illuminating               0.0      NaN  NaN      NaN
# foreign_policy_topic_illuminating            0.0      NaN  NaN      NaN
# governance_topic_illuminating                0.0      NaN  NaN      NaN
# health_topic_illuminating                    0.0      NaN  NaN      NaN
# immigration_topic_illuminating               0.0      NaN  NaN      NaN
# lgbtq_issues_topic_illuminating              0.0      NaN  NaN      NaN
# military_topic_illuminating                  0.0      NaN  NaN      NaN
# race_and_ethnicity_topic_illuminating        0.0      NaN  NaN      NaN
# safety_topic_illuminating                    0.0      NaN  NaN      NaN
# social_and_cultural_topic_illuminating       0.0      NaN  NaN      NaN
# technology_and_privacy_topic_illuminating    0.0      NaN  NaN      NaN
# womens_issue_topic_illuminating              0.0      NaN  NaN      NaN
# incivility_illuminating                      0.0      NaN  NaN      NaN
# scam_illuminating                            0.0      NaN  NaN      NaN
# freefair_illuminating                        1.0      0.0  NaN      0.0
# fraud_illuminating                           1.0      0.0  NaN      0.0
#
#                                                25%      50%      75%      max
# retweetCount                                 101.0    101.0    101.0    101.0
# replyCount                                    26.0     26.0     26.0     26.0
# likeCount                                    290.0    290.0    290.0    290.0
# quoteCount                                    13.0     13.0     13.0     13.0
# viewCount                                  24795.0  24795.0  24795.0  24795.0
# bookmarkCount                                  5.0      5.0      5.0      5.0
# quoteId                                        NaN      NaN      NaN      NaN
# inReplyToId                                    NaN      NaN      NaN      NaN
# election_integrity_Truth_illuminating          NaN      NaN      NaN      NaN
# advocacy_msg_type_illuminating                 NaN      NaN      NaN      NaN
# issue_msg_type_illuminating                    NaN      NaN      NaN      NaN
# attack_msg_type_illuminating                   NaN      NaN      NaN      NaN
# image_msg_type_illuminating                    NaN      NaN      NaN      NaN
# cta_msg_type_illuminating                      NaN      NaN      NaN      NaN
# engagement_cta_subtype_illuminating            NaN      NaN      NaN      NaN
# fundraising_cta_subtype_illuminating           NaN      NaN      NaN      NaN
# voting_cta_subtype_illuminating                NaN      NaN      NaN      NaN
# covid_topic_illuminating                       NaN      NaN      NaN      NaN
# economy_topic_illuminating                     NaN      NaN      NaN      NaN
# education_topic_illuminating                   NaN      NaN      NaN      NaN
# environment_topic_illuminating                 NaN      NaN      NaN      NaN
# foreign_policy_topic_illuminating              NaN      NaN      NaN      NaN
# governance_topic_illuminating                  NaN      NaN      NaN      NaN
# health_topic_illuminating                      NaN      NaN      NaN      NaN
# immigration_topic_illuminating                 NaN      NaN      NaN      NaN
# lgbtq_issues_topic_illuminating                NaN      NaN      NaN      NaN
# military_topic_illuminating                    NaN      NaN      NaN      NaN
# race_and_ethnicity_topic_illuminating          NaN      NaN      NaN      NaN
# safety_topic_illuminating                      NaN      NaN      NaN      NaN
# social_and_cultural_topic_illuminating         NaN      NaN      NaN      NaN
# technology_and_privacy_topic_illuminating      NaN      NaN      NaN      NaN
# womens_issue_topic_illuminating                NaN      NaN      NaN      NaN
# incivility_illuminating                        NaN      NaN      NaN      NaN
# scam_illuminating                              NaN      NaN      NaN      NaN
# freefair_illuminating                          0.0      0.0      0.0      0.0
# fraud_illuminating                             0.0      0.0      0.0      0.0
#
# 📝 Non-Numeric Columns:
# - id:
#     Unique values  : 1
#     Most frequent  : '00008766c5fc0cb57b4d76792f8f1cea9ead8cf29217dd5bc2e3bafb9ba9fab9' (1 times)
# - url:
#     Unique values  : 1
#     Most frequent  : '712068b331ee4ceee2a40682c49e0b078596ced3767767263272b953f99ff058' (1 times)
# - source:
#     Unique values  : 1
#     Most frequent  : 'Twitter for iPhone' (1 times)
# - createdAt:
#     Unique values  : 1
#     Most frequent  : '2024-07-11 19:30:27' (1 times)
# - lang:
#     Unique values  : 1
#     Most frequent  : 'en' (1 times)
# - isReply:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isRetweet:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isQuote:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isConversationControlled:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - month_year:
#     Unique values  : 1
#     Most frequent  : '2024-07' (1 times)
# - illuminating_scored_message:
#     Unique values  : 1
#     Most frequent  : '5258222ac84860f3188646e049ec5522cc22f774929222ff73e9d6b2a0c5a136' (1 times)
#
# ============================================================
# 📁 Group: id = 00024b0fcb3cb0476d8eae457f7471bd8322c33416cc182b1bbd73e001fe977b
# ============================================================
#
# 📊 Numeric Columns:
#                                            count      mean  std       min  \
# retweetCount                                 1.0    1976.0  NaN    1976.0
# replyCount                                   1.0    1965.0  NaN    1965.0
# likeCount                                    1.0    9522.0  NaN    9522.0
# quoteCount                                   1.0     219.0  NaN     219.0
# viewCount                                    1.0  408290.0  NaN  408290.0
# bookmarkCount                                1.0     207.0  NaN     207.0
# quoteId                                      0.0       NaN  NaN       NaN
# inReplyToId                                  0.0       NaN  NaN       NaN
# election_integrity_Truth_illuminating        1.0       0.0  NaN       0.0
# advocacy_msg_type_illuminating               1.0       0.0  NaN       0.0
# issue_msg_type_illuminating                  1.0       0.0  NaN       0.0
# attack_msg_type_illuminating                 1.0       0.0  NaN       0.0
# image_msg_type_illuminating                  1.0       1.0  NaN       1.0
# cta_msg_type_illuminating                    1.0       0.0  NaN       0.0
# engagement_cta_subtype_illuminating          1.0       0.0  NaN       0.0
# fundraising_cta_subtype_illuminating         1.0       0.0  NaN       0.0
# voting_cta_subtype_illuminating              1.0       0.0  NaN       0.0
# covid_topic_illuminating                     1.0       0.0  NaN       0.0
# economy_topic_illuminating                   1.0       0.0  NaN       0.0
# education_topic_illuminating                 1.0       0.0  NaN       0.0
# environment_topic_illuminating               1.0       0.0  NaN       0.0
# foreign_policy_topic_illuminating            1.0       0.0  NaN       0.0
# governance_topic_illuminating                1.0       0.0  NaN       0.0
# health_topic_illuminating                    1.0       0.0  NaN       0.0
# immigration_topic_illuminating               1.0       0.0  NaN       0.0
# lgbtq_issues_topic_illuminating              1.0       0.0  NaN       0.0
# military_topic_illuminating                  1.0       0.0  NaN       0.0
# race_and_ethnicity_topic_illuminating        1.0       0.0  NaN       0.0
# safety_topic_illuminating                    1.0       0.0  NaN       0.0
# social_and_cultural_topic_illuminating       1.0       0.0  NaN       0.0
# technology_and_privacy_topic_illuminating    1.0       0.0  NaN       0.0
# womens_issue_topic_illuminating              1.0       0.0  NaN       0.0
# incivility_illuminating                      1.0       0.0  NaN       0.0
# scam_illuminating                            1.0       0.0  NaN       0.0
# freefair_illuminating                        1.0       0.0  NaN       0.0
# fraud_illuminating                           1.0       0.0  NaN       0.0
#
#                                                 25%       50%       75%  \
# retweetCount                                 1976.0    1976.0    1976.0
# replyCount                                   1965.0    1965.0    1965.0
# likeCount                                    9522.0    9522.0    9522.0
# quoteCount                                    219.0     219.0     219.0
# viewCount                                  408290.0  408290.0  408290.0
# bookmarkCount                                 207.0     207.0     207.0
# quoteId                                         NaN       NaN       NaN
# inReplyToId                                     NaN       NaN       NaN
# election_integrity_Truth_illuminating           0.0       0.0       0.0
# advocacy_msg_type_illuminating                  0.0       0.0       0.0
# issue_msg_type_illuminating                     0.0       0.0       0.0
# attack_msg_type_illuminating                    0.0       0.0       0.0
# image_msg_type_illuminating                     1.0       1.0       1.0
# cta_msg_type_illuminating                       0.0       0.0       0.0
# engagement_cta_subtype_illuminating             0.0       0.0       0.0
# fundraising_cta_subtype_illuminating            0.0       0.0       0.0
# voting_cta_subtype_illuminating                 0.0       0.0       0.0
# covid_topic_illuminating                        0.0       0.0       0.0
# economy_topic_illuminating                      0.0       0.0       0.0
# education_topic_illuminating                    0.0       0.0       0.0
# environment_topic_illuminating                  0.0       0.0       0.0
# foreign_policy_topic_illuminating               0.0       0.0       0.0
# governance_topic_illuminating                   0.0       0.0       0.0
# health_topic_illuminating                       0.0       0.0       0.0
# immigration_topic_illuminating                  0.0       0.0       0.0
# lgbtq_issues_topic_illuminating                 0.0       0.0       0.0
# military_topic_illuminating                     0.0       0.0       0.0
# race_and_ethnicity_topic_illuminating           0.0       0.0       0.0
# safety_topic_illuminating                       0.0       0.0       0.0
# social_and_cultural_topic_illuminating          0.0       0.0       0.0
# technology_and_privacy_topic_illuminating       0.0       0.0       0.0
# womens_issue_topic_illuminating                 0.0       0.0       0.0
# incivility_illuminating                         0.0       0.0       0.0
# scam_illuminating                               0.0       0.0       0.0
# freefair_illuminating                           0.0       0.0       0.0
# fraud_illuminating                              0.0       0.0       0.0
#
#                                                 max
# retweetCount                                 1976.0
# replyCount                                   1965.0
# likeCount                                    9522.0
# quoteCount                                    219.0
# viewCount                                  408290.0
# bookmarkCount                                 207.0
# quoteId                                         NaN
# inReplyToId                                     NaN
# election_integrity_Truth_illuminating           0.0
# advocacy_msg_type_illuminating                  0.0
# issue_msg_type_illuminating                     0.0
# attack_msg_type_illuminating                    0.0
# image_msg_type_illuminating                     1.0
# cta_msg_type_illuminating                       0.0
# engagement_cta_subtype_illuminating             0.0
# fundraising_cta_subtype_illuminating            0.0
# voting_cta_subtype_illuminating                 0.0
# covid_topic_illuminating                        0.0
# economy_topic_illuminating                      0.0
# education_topic_illuminating                    0.0
# environment_topic_illuminating                  0.0
# foreign_policy_topic_illuminating               0.0
# governance_topic_illuminating                   0.0
# health_topic_illuminating                       0.0
# immigration_topic_illuminating                  0.0
# lgbtq_issues_topic_illuminating                 0.0
# military_topic_illuminating                     0.0
# race_and_ethnicity_topic_illuminating           0.0
# safety_topic_illuminating                       0.0
# social_and_cultural_topic_illuminating          0.0
# technology_and_privacy_topic_illuminating       0.0
# womens_issue_topic_illuminating                 0.0
# incivility_illuminating                         0.0
# scam_illuminating                               0.0
# freefair_illuminating                           0.0
# fraud_illuminating                              0.0
#
# 📝 Non-Numeric Columns:
# - id:
#     Unique values  : 1
#     Most frequent  : '00024b0fcb3cb0476d8eae457f7471bd8322c33416cc182b1bbd73e001fe977b' (1 times)
# - url:
#     Unique values  : 1
#     Most frequent  : '6506333580d4ca1d18e60f70e16a4ba31ee5e7c9d6234608207e1a870774ea88' (1 times)
# - source:
#     Unique values  : 1
#     Most frequent  : 'Twitter Web App' (1 times)
# - createdAt:
#     Unique values  : 1
#     Most frequent  : '2024-09-20 01:09:30' (1 times)
# - lang:
#     Unique values  : 1
#     Most frequent  : 'en' (1 times)
# - isReply:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isRetweet:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isQuote:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isConversationControlled:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - month_year:
#     Unique values  : 1
#     Most frequent  : '2024-09' (1 times)
# - illuminating_scored_message:
#     Unique values  : 1
#     Most frequent  : '1b0c448f02ac302563362283f3563243e5e39d1338dab67a177df93e626c51b2' (1 times)
#
# ============================================================
# 📁 Group: id = 00042707dea2d809b45b5b60b9474f146849cb85936c5ea5f8adeb5842256ef9
# ============================================================
#
# 📊 Numeric Columns:
#                                            count      mean  std       min  \
# retweetCount                                 1.0    1457.0  NaN    1457.0
# replyCount                                   1.0     223.0  NaN     223.0
# likeCount                                    1.0    6266.0  NaN    6266.0
# quoteCount                                   1.0      96.0  NaN      96.0
# viewCount                                    1.0  313920.0  NaN  313920.0
# bookmarkCount                                1.0     341.0  NaN     341.0
# quoteId                                      0.0       NaN  NaN       NaN
# inReplyToId                                  0.0       NaN  NaN       NaN
# election_integrity_Truth_illuminating        1.0       0.0  NaN       0.0
# advocacy_msg_type_illuminating               1.0       0.0  NaN       0.0
# issue_msg_type_illuminating                  1.0       0.0  NaN       0.0
# attack_msg_type_illuminating                 1.0       1.0  NaN       1.0
# image_msg_type_illuminating                  1.0       1.0  NaN       1.0
# cta_msg_type_illuminating                    1.0       0.0  NaN       0.0
# engagement_cta_subtype_illuminating          1.0       0.0  NaN       0.0
# fundraising_cta_subtype_illuminating         1.0       0.0  NaN       0.0
# voting_cta_subtype_illuminating              1.0       0.0  NaN       0.0
# covid_topic_illuminating                     1.0       0.0  NaN       0.0
# economy_topic_illuminating                   1.0       0.0  NaN       0.0
# education_topic_illuminating                 1.0       0.0  NaN       0.0
# environment_topic_illuminating               1.0       0.0  NaN       0.0
# foreign_policy_topic_illuminating            1.0       0.0  NaN       0.0
# governance_topic_illuminating                1.0       0.0  NaN       0.0
# health_topic_illuminating                    1.0       0.0  NaN       0.0
# immigration_topic_illuminating               1.0       0.0  NaN       0.0
# lgbtq_issues_topic_illuminating              1.0       0.0  NaN       0.0
# military_topic_illuminating                  1.0       0.0  NaN       0.0
# race_and_ethnicity_topic_illuminating        1.0       0.0  NaN       0.0
# safety_topic_illuminating                    1.0       0.0  NaN       0.0
# social_and_cultural_topic_illuminating       1.0       0.0  NaN       0.0
# technology_and_privacy_topic_illuminating    1.0       0.0  NaN       0.0
# womens_issue_topic_illuminating              1.0       0.0  NaN       0.0
# incivility_illuminating                      1.0       0.0  NaN       0.0
# scam_illuminating                            1.0       0.0  NaN       0.0
# freefair_illuminating                        1.0       0.0  NaN       0.0
# fraud_illuminating                           1.0       0.0  NaN       0.0
#
#                                                 25%       50%       75%  \
# retweetCount                                 1457.0    1457.0    1457.0
# replyCount                                    223.0     223.0     223.0
# likeCount                                    6266.0    6266.0    6266.0
# quoteCount                                     96.0      96.0      96.0
# viewCount                                  313920.0  313920.0  313920.0
# bookmarkCount                                 341.0     341.0     341.0
# quoteId                                         NaN       NaN       NaN
# inReplyToId                                     NaN       NaN       NaN
# election_integrity_Truth_illuminating           0.0       0.0       0.0
# advocacy_msg_type_illuminating                  0.0       0.0       0.0
# issue_msg_type_illuminating                     0.0       0.0       0.0
# attack_msg_type_illuminating                    1.0       1.0       1.0
# image_msg_type_illuminating                     1.0       1.0       1.0
# cta_msg_type_illuminating                       0.0       0.0       0.0
# engagement_cta_subtype_illuminating             0.0       0.0       0.0
# fundraising_cta_subtype_illuminating            0.0       0.0       0.0
# voting_cta_subtype_illuminating                 0.0       0.0       0.0
# covid_topic_illuminating                        0.0       0.0       0.0
# economy_topic_illuminating                      0.0       0.0       0.0
# education_topic_illuminating                    0.0       0.0       0.0
# environment_topic_illuminating                  0.0       0.0       0.0
# foreign_policy_topic_illuminating               0.0       0.0       0.0
# governance_topic_illuminating                   0.0       0.0       0.0
# health_topic_illuminating                       0.0       0.0       0.0
# immigration_topic_illuminating                  0.0       0.0       0.0
# lgbtq_issues_topic_illuminating                 0.0       0.0       0.0
# military_topic_illuminating                     0.0       0.0       0.0
# race_and_ethnicity_topic_illuminating           0.0       0.0       0.0
# safety_topic_illuminating                       0.0       0.0       0.0
# social_and_cultural_topic_illuminating          0.0       0.0       0.0
# technology_and_privacy_topic_illuminating       0.0       0.0       0.0
# womens_issue_topic_illuminating                 0.0       0.0       0.0
# incivility_illuminating                         0.0       0.0       0.0
# scam_illuminating                               0.0       0.0       0.0
# freefair_illuminating                           0.0       0.0       0.0
# fraud_illuminating                              0.0       0.0       0.0
#
#                                                 max
# retweetCount                                 1457.0
# replyCount                                    223.0
# likeCount                                    6266.0
# quoteCount                                     96.0
# viewCount                                  313920.0
# bookmarkCount                                 341.0
# quoteId                                         NaN
# inReplyToId                                     NaN
# election_integrity_Truth_illuminating           0.0
# advocacy_msg_type_illuminating                  0.0
# issue_msg_type_illuminating                     0.0
# attack_msg_type_illuminating                    1.0
# image_msg_type_illuminating                     1.0
# cta_msg_type_illuminating                       0.0
# engagement_cta_subtype_illuminating             0.0
# fundraising_cta_subtype_illuminating            0.0
# voting_cta_subtype_illuminating                 0.0
# covid_topic_illuminating                        0.0
# economy_topic_illuminating                      0.0
# education_topic_illuminating                    0.0
# environment_topic_illuminating                  0.0
# foreign_policy_topic_illuminating               0.0
# governance_topic_illuminating                   0.0
# health_topic_illuminating                       0.0
# immigration_topic_illuminating                  0.0
# lgbtq_issues_topic_illuminating                 0.0
# military_topic_illuminating                     0.0
# race_and_ethnicity_topic_illuminating           0.0
# safety_topic_illuminating                       0.0
# social_and_cultural_topic_illuminating          0.0
# technology_and_privacy_topic_illuminating       0.0
# womens_issue_topic_illuminating                 0.0
# incivility_illuminating                         0.0
# scam_illuminating                               0.0
# freefair_illuminating                           0.0
# fraud_illuminating                              0.0
#
# 📝 Non-Numeric Columns:
# - id:
#     Unique values  : 1
#     Most frequent  : '00042707dea2d809b45b5b60b9474f146849cb85936c5ea5f8adeb5842256ef9' (1 times)
# - url:
#     Unique values  : 1
#     Most frequent  : '745cb76c6ec6d951435629f7e10bd7b177e7eba7a49cb50b6165c739168822a9' (1 times)
# - source:
#     Unique values  : 1
#     Most frequent  : 'Twitter Web App' (1 times)
# - createdAt:
#     Unique values  : 1
#     Most frequent  : '2024-09-19 02:43:49' (1 times)
# - lang:
#     Unique values  : 1
#     Most frequent  : 'en' (1 times)
# - isReply:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isRetweet:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isQuote:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isConversationControlled:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - month_year:
#     Unique values  : 1
#     Most frequent  : '2024-09' (1 times)
# - illuminating_scored_message:
#     Unique values  : 1
#     Most frequent  : '399034f7941aa17ffad04b38c81ed06e6fac6645922f6f0bc9c6ed4522de726e' (1 times)
#
# ============================================================
# 📁 Group: id = 0004752ef0c4ca595974b62e2a2e4ff34901abe0b5f0794c836cdbd9ff5743ce
# ============================================================
#
# 📊 Numeric Columns:
#                                            count     mean  std      min  \
# retweetCount                                 1.0    212.0  NaN    212.0
# replyCount                                   1.0     50.0  NaN     50.0
# likeCount                                    1.0    598.0  NaN    598.0
# quoteCount                                   1.0      5.0  NaN      5.0
# viewCount                                    1.0  20566.0  NaN  20566.0
# bookmarkCount                                1.0      3.0  NaN      3.0
# quoteId                                      0.0      NaN  NaN      NaN
# inReplyToId                                  0.0      NaN  NaN      NaN
# election_integrity_Truth_illuminating        1.0      0.0  NaN      0.0
# advocacy_msg_type_illuminating               1.0      1.0  NaN      1.0
# issue_msg_type_illuminating                  1.0      1.0  NaN      1.0
# attack_msg_type_illuminating                 1.0      1.0  NaN      1.0
# image_msg_type_illuminating                  1.0      1.0  NaN      1.0
# cta_msg_type_illuminating                    1.0      0.0  NaN      0.0
# engagement_cta_subtype_illuminating          1.0      0.0  NaN      0.0
# fundraising_cta_subtype_illuminating         1.0      0.0  NaN      0.0
# voting_cta_subtype_illuminating              1.0      0.0  NaN      0.0
# covid_topic_illuminating                     1.0      0.0  NaN      0.0
# economy_topic_illuminating                   1.0      0.0  NaN      0.0
# education_topic_illuminating                 1.0      0.0  NaN      0.0
# environment_topic_illuminating               1.0      0.0  NaN      0.0
# foreign_policy_topic_illuminating            1.0      0.0  NaN      0.0
# governance_topic_illuminating                1.0      0.0  NaN      0.0
# health_topic_illuminating                    1.0      0.0  NaN      0.0
# immigration_topic_illuminating               1.0      0.0  NaN      0.0
# lgbtq_issues_topic_illuminating              1.0      0.0  NaN      0.0
# military_topic_illuminating                  1.0      0.0  NaN      0.0
# race_and_ethnicity_topic_illuminating        1.0      0.0  NaN      0.0
# safety_topic_illuminating                    1.0      0.0  NaN      0.0
# social_and_cultural_topic_illuminating       1.0      0.0  NaN      0.0
# technology_and_privacy_topic_illuminating    1.0      0.0  NaN      0.0
# womens_issue_topic_illuminating              1.0      0.0  NaN      0.0
# incivility_illuminating                      1.0      0.0  NaN      0.0
# scam_illuminating                            1.0      0.0  NaN      0.0
# freefair_illuminating                        1.0      0.0  NaN      0.0
# fraud_illuminating                           1.0      0.0  NaN      0.0
#
#                                                25%      50%      75%      max
# retweetCount                                 212.0    212.0    212.0    212.0
# replyCount                                    50.0     50.0     50.0     50.0
# likeCount                                    598.0    598.0    598.0    598.0
# quoteCount                                     5.0      5.0      5.0      5.0
# viewCount                                  20566.0  20566.0  20566.0  20566.0
# bookmarkCount                                  3.0      3.0      3.0      3.0
# quoteId                                        NaN      NaN      NaN      NaN
# inReplyToId                                    NaN      NaN      NaN      NaN
# election_integrity_Truth_illuminating          0.0      0.0      0.0      0.0
# advocacy_msg_type_illuminating                 1.0      1.0      1.0      1.0
# issue_msg_type_illuminating                    1.0      1.0      1.0      1.0
# attack_msg_type_illuminating                   1.0      1.0      1.0      1.0
# image_msg_type_illuminating                    1.0      1.0      1.0      1.0
# cta_msg_type_illuminating                      0.0      0.0      0.0      0.0
# engagement_cta_subtype_illuminating            0.0      0.0      0.0      0.0
# ...
# education_topic_illuminating               0.000000e+00  0.000000e+00
# environment_topic_illuminating             0.000000e+00  0.000000e+00
# foreign_policy_topic_illuminating          0.000000e+00  0.000000e+00
# governance_topic_illuminating              0.000000e+00  0.000000e+00
# health_topic_illuminating                  0.000000e+00  0.000000e+00
# immigration_topic_illuminating             0.000000e+00  0.000000e+00
# lgbtq_issues_topic_illuminating            0.000000e+00  0.000000e+00
# military_topic_illuminating                0.000000e+00  0.000000e+00
# race_and_ethnicity_topic_illuminating      0.000000e+00  0.000000e+00
# safety_topic_illuminating                  0.000000e+00  0.000000e+00
# social_and_cultural_topic_illuminating     0.000000e+00  0.000000e+00
# technology_and_privacy_topic_illuminating  0.000000e+00  0.000000e+00
# womens_issue_topic_illuminating            0.000000e+00  0.000000e+00
# incivility_illuminating                    0.000000e+00  0.000000e+00
# scam_illuminating                          0.000000e+00  0.000000e+00
# freefair_illuminating                      0.000000e+00  0.000000e+00
# fraud_illuminating                         0.000000e+00  0.000000e+00
#
#                                                     max
# retweetCount                               1.790000e+02
# replyCount                                 1.500000e+01
# likeCount                                  4.300000e+02
# quoteCount                                 2.000000e+00
# viewCount                                  1.714500e+04
# bookmarkCount                              1.000000e+00
# quoteId                                    1.840968e+18
# inReplyToId                                         NaN
# election_integrity_Truth_illuminating      0.000000e+00
# advocacy_msg_type_illuminating             1.000000e+00
# issue_msg_type_illuminating                1.000000e+00
# attack_msg_type_illuminating               0.000000e+00
# image_msg_type_illuminating                0.000000e+00
# cta_msg_type_illuminating                  0.000000e+00
# engagement_cta_subtype_illuminating        0.000000e+00
# fundraising_cta_subtype_illuminating       0.000000e+00
# voting_cta_subtype_illuminating            0.000000e+00
# covid_topic_illuminating                   0.000000e+00
# economy_topic_illuminating                 1.000000e+00
# education_topic_illuminating               0.000000e+00
# environment_topic_illuminating             0.000000e+00
# foreign_policy_topic_illuminating          0.000000e+00
# governance_topic_illuminating              0.000000e+00
# health_topic_illuminating                  0.000000e+00
# immigration_topic_illuminating             0.000000e+00
# lgbtq_issues_topic_illuminating            0.000000e+00
# military_topic_illuminating                0.000000e+00
# race_and_ethnicity_topic_illuminating      0.000000e+00
# safety_topic_illuminating                  0.000000e+00
# social_and_cultural_topic_illuminating     0.000000e+00
# technology_and_privacy_topic_illuminating  0.000000e+00
# womens_issue_topic_illuminating            0.000000e+00
# incivility_illuminating                    0.000000e+00
# scam_illuminating                          0.000000e+00
# freefair_illuminating                      0.000000e+00
# fraud_illuminating                         0.000000e+00
#
# 📝 Non-Numeric Columns:
# - id:
#     Unique values  : 1
#     Most frequent  : 'aabbf3f2c3a4513c54f0d0242b24eeed781abf9bb4cc28f65433a438d0797d54' (1 times)
# - url:
#     Unique values  : 1
#     Most frequent  : 'eef634b02e91a0c7b25254b97d37dfaa83a31794420a75e37938a7cfeb55a455' (1 times)
# - source:
#     Unique values  : 1
#     Most frequent  : 'Twitter for iPhone' (1 times)
# - createdAt:
#     Unique values  : 1
#     Most frequent  : '2024-10-01 19:07:10' (1 times)
# - lang:
#     Unique values  : 1
#     Most frequent  : 'en' (1 times)
# - isReply:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isRetweet:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isQuote:
#     Unique values  : 1
#     Most frequent  : 'True' (1 times)
# - isConversationControlled:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - month_year:
#     Unique values  : 1
#     Most frequent  : '2024-10' (1 times)
# - illuminating_scored_message:
#     Unique values  : 1
#     Most frequent  : 'c5260c93e5b96bcb30f4db66517b226b52159d67d0269a15ae46003c7d7a86dd' (1 times)
#
# ============================================================
# 🔗 Group: id = aad49acaad1abee9ef8a5dc09e0e7ee94ce26cb67fd89227efd26afd08e0c3cb, quoteId = 1.816864538651738e+18
# ============================================================
#
# 📊 Numeric Columns:
#                                            count          mean  std  \
# retweetCount                                 1.0  3.683000e+03  NaN
# replyCount                                   1.0  1.550000e+02  NaN
# likeCount                                    1.0  9.314000e+03  NaN
# quoteCount                                   1.0  5.500000e+01  NaN
# viewCount                                    1.0  1.573140e+05  NaN
# bookmarkCount                                1.0  1.790000e+02  NaN
# quoteId                                      1.0  1.816865e+18  NaN
# inReplyToId                                  0.0           NaN  NaN
# election_integrity_Truth_illuminating        0.0           NaN  NaN
# advocacy_msg_type_illuminating               0.0           NaN  NaN
# issue_msg_type_illuminating                  0.0           NaN  NaN
# attack_msg_type_illuminating                 0.0           NaN  NaN
# image_msg_type_illuminating                  0.0           NaN  NaN
# cta_msg_type_illuminating                    0.0           NaN  NaN
# engagement_cta_subtype_illuminating          0.0           NaN  NaN
# fundraising_cta_subtype_illuminating         0.0           NaN  NaN
# voting_cta_subtype_illuminating              0.0           NaN  NaN
# covid_topic_illuminating                     0.0           NaN  NaN
# economy_topic_illuminating                   0.0           NaN  NaN
# education_topic_illuminating                 0.0           NaN  NaN
# environment_topic_illuminating               0.0           NaN  NaN
# foreign_policy_topic_illuminating            0.0           NaN  NaN
# governance_topic_illuminating                0.0           NaN  NaN
# health_topic_illuminating                    0.0           NaN  NaN
# immigration_topic_illuminating               0.0           NaN  NaN
# lgbtq_issues_topic_illuminating              0.0           NaN  NaN
# military_topic_illuminating                  0.0           NaN  NaN
# race_and_ethnicity_topic_illuminating        0.0           NaN  NaN
# safety_topic_illuminating                    0.0           NaN  NaN
# social_and_cultural_topic_illuminating       0.0           NaN  NaN
# technology_and_privacy_topic_illuminating    0.0           NaN  NaN
# womens_issue_topic_illuminating              0.0           NaN  NaN
# incivility_illuminating                      0.0           NaN  NaN
# scam_illuminating                            0.0           NaN  NaN
# freefair_illuminating                        1.0  0.000000e+00  NaN
# fraud_illuminating                           1.0  0.000000e+00  NaN
#
#                                                     min           25%  \
# retweetCount                               3.683000e+03  3.683000e+03
# replyCount                                 1.550000e+02  1.550000e+02
# likeCount                                  9.314000e+03  9.314000e+03
# quoteCount                                 5.500000e+01  5.500000e+01
# viewCount                                  1.573140e+05  1.573140e+05
# bookmarkCount                              1.790000e+02  1.790000e+02
# quoteId                                    1.816865e+18  1.816865e+18
# inReplyToId                                         NaN           NaN
# election_integrity_Truth_illuminating               NaN           NaN
# advocacy_msg_type_illuminating                      NaN           NaN
# issue_msg_type_illuminating                         NaN           NaN
# attack_msg_type_illuminating                        NaN           NaN
# image_msg_type_illuminating                         NaN           NaN
# cta_msg_type_illuminating                           NaN           NaN
# engagement_cta_subtype_illuminating                 NaN           NaN
# fundraising_cta_subtype_illuminating                NaN           NaN
# voting_cta_subtype_illuminating                     NaN           NaN
# covid_topic_illuminating                            NaN           NaN
# economy_topic_illuminating                          NaN           NaN
# education_topic_illuminating                        NaN           NaN
# environment_topic_illuminating                      NaN           NaN
# foreign_policy_topic_illuminating                   NaN           NaN
# governance_topic_illuminating                       NaN           NaN
# health_topic_illuminating                           NaN           NaN
# immigration_topic_illuminating                      NaN           NaN
# lgbtq_issues_topic_illuminating                     NaN           NaN
# military_topic_illuminating                         NaN           NaN
# race_and_ethnicity_topic_illuminating               NaN           NaN
# safety_topic_illuminating                           NaN           NaN
# social_and_cultural_topic_illuminating              NaN           NaN
# technology_and_privacy_topic_illuminating           NaN           NaN
# womens_issue_topic_illuminating                     NaN           NaN
# incivility_illuminating                             NaN           NaN
# scam_illuminating                                   NaN           NaN
# freefair_illuminating                      0.000000e+00  0.000000e+00
# fraud_illuminating                         0.000000e+00  0.000000e+00
#
#                                                     50%           75%  \
# retweetCount                               3.683000e+03  3.683000e+03
# replyCount                                 1.550000e+02  1.550000e+02
# likeCount                                  9.314000e+03  9.314000e+03
# quoteCount                                 5.500000e+01  5.500000e+01
# viewCount                                  1.573140e+05  1.573140e+05
# bookmarkCount                              1.790000e+02  1.790000e+02
# quoteId                                    1.816865e+18  1.816865e+18
# inReplyToId                                         NaN           NaN
# election_integrity_Truth_illuminating               NaN           NaN
# advocacy_msg_type_illuminating                      NaN           NaN
# issue_msg_type_illuminating                         NaN           NaN
# attack_msg_type_illuminating                        NaN           NaN
# image_msg_type_illuminating                         NaN           NaN
# cta_msg_type_illuminating                           NaN           NaN
# engagement_cta_subtype_illuminating                 NaN           NaN
# fundraising_cta_subtype_illuminating                NaN           NaN
# voting_cta_subtype_illuminating                     NaN           NaN
# covid_topic_illuminating                            NaN           NaN
# economy_topic_illuminating                          NaN           NaN
# education_topic_illuminating                        NaN           NaN
# environment_topic_illuminating                      NaN           NaN
# foreign_policy_topic_illuminating                   NaN           NaN
# governance_topic_illuminating                       NaN           NaN
# health_topic_illuminating                           NaN           NaN
# immigration_topic_illuminating                      NaN           NaN
# lgbtq_issues_topic_illuminating                     NaN           NaN
# military_topic_illuminating                         NaN           NaN
# race_and_ethnicity_topic_illuminating               NaN           NaN
# safety_topic_illuminating                           NaN           NaN
# social_and_cultural_topic_illuminating              NaN           NaN
# technology_and_privacy_topic_illuminating           NaN           NaN
# womens_issue_topic_illuminating                     NaN           NaN
# incivility_illuminating                             NaN           NaN
# scam_illuminating                                   NaN           NaN
# freefair_illuminating                      0.000000e+00  0.000000e+00
# fraud_illuminating                         0.000000e+00  0.000000e+00
#
#                                                     max
# retweetCount                               3.683000e+03
# replyCount                                 1.550000e+02
# likeCount                                  9.314000e+03
# quoteCount                                 5.500000e+01
# viewCount                                  1.573140e+05
# bookmarkCount                              1.790000e+02
# quoteId                                    1.816865e+18
# inReplyToId                                         NaN
# election_integrity_Truth_illuminating               NaN
# advocacy_msg_type_illuminating                      NaN
# issue_msg_type_illuminating                         NaN
# attack_msg_type_illuminating                        NaN
# image_msg_type_illuminating                         NaN
# cta_msg_type_illuminating                           NaN
# engagement_cta_subtype_illuminating                 NaN
# fundraising_cta_subtype_illuminating                NaN
# voting_cta_subtype_illuminating                     NaN
# covid_topic_illuminating                            NaN
# economy_topic_illuminating                          NaN
# education_topic_illuminating                        NaN
# environment_topic_illuminating                      NaN
# foreign_policy_topic_illuminating                   NaN
# governance_topic_illuminating                       NaN
# health_topic_illuminating                           NaN
# immigration_topic_illuminating                      NaN
# lgbtq_issues_topic_illuminating                     NaN
# military_topic_illuminating                         NaN
# race_and_ethnicity_topic_illuminating               NaN
# safety_topic_illuminating                           NaN
# social_and_cultural_topic_illuminating              NaN
# technology_and_privacy_topic_illuminating           NaN
# womens_issue_topic_illuminating                     NaN
# incivility_illuminating                             NaN
# scam_illuminating                                   NaN
# freefair_illuminating                      0.000000e+00
# fraud_illuminating                         0.000000e+00
#
# 📝 Non-Numeric Columns:
# - id:
#     Unique values  : 1
#     Most frequent  : 'aad49acaad1abee9ef8a5dc09e0e7ee94ce26cb67fd89227efd26afd08e0c3cb' (1 times)
# - url:
#     Unique values  : 1
#     Most frequent  : 'd7398a32de3f7da4a906a38c2b975ad53224704ff1962554fcafd0ae9c45ced6' (1 times)
# - source:
#     Unique values  : 1
#     Most frequent  : 'Twitter Web App' (1 times)
# - createdAt:
#     Unique values  : 1
#     Most frequent  : '2024-07-26 18:01:47' (1 times)
# - lang:
#     Unique values  : 1
#     Most frequent  : 'en' (1 times)
# - isReply:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isRetweet:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - isQuote:
#     Unique values  : 1
#     Most frequent  : 'True' (1 times)
# - isConversationControlled:
#     Unique values  : 1
#     Most frequent  : 'False' (1 times)
# - month_year:
#     Unique values  : 1
#     Most frequent  : '2024-07' (1 times)
# - illuminating_scored_message:
#     Unique values  : 1
#     Most frequent  : 'cb4f9df85f81b56b73d8924fe6cfa7b5bf39970ea69f4b1f07a7907ff7c24bdc' (1 times)
