# %%
import csv
import math
from collections import defaultdict, Counter

FILE_PATH = "2024_fb_ads_president_scored_anon.csv"

def is_number(s):
    try:
        float(s)
        return True
    except:
        return False

def mean(lst):
    return sum(lst) / len(lst) if lst else 0

def std_dev(lst):
    if len(lst) < 2:
        return 0
    avg = mean(lst)
    variance = sum((x - avg) ** 2 for x in lst) / len(lst)
    return math.sqrt(variance)

def read_csv(file_path):
    with open(file_path, encoding="utf-8") as f:
        reader = csv.DictReader(f)
        return list(reader)

def summarize(data, label="Overall Summary"):
    print(f"\n{'=' * 60}")
    print(f"{label}")
    print(f"{'=' * 60}")

    if not data:
        print("No records available.\n")
        return

    columns = data[0].keys()
    for col in columns:
        values = [row[col].strip() for row in data if row[col].strip()]
        numeric_vals = [float(v) for v in values if is_number(v)]

        if numeric_vals:
            print(f"\n📊 {col} (Numeric)")
            print(f"    Count   : {len(numeric_vals)}")
            print(f"    Mean    : {mean(numeric_vals):.2f}")
            print(f"    Min     : {min(numeric_vals)}")
            print(f"    Max     : {max(numeric_vals)}")
            print(f"    Std Dev : {std_dev(numeric_vals):.2f}")
        elif values:
            counter = Counter(values)
            most_common = counter.most_common(1)[0]
            print(f"\n📝 {col} (Categorical)")
            print(f"    Unique Values : {len(counter)}")
            print(f"    Most Frequent : '{most_common[0]}' ({most_common[1]} times)")
    print()

def group_by(data, keys):
    groups = defaultdict(list)
    for row in data:
        key = tuple(row[k] for k in keys)
        groups[key].append(row)
    return groups

if __name__ == "__main__":
    data = read_csv(FILE_PATH)

    # Overall Summary
    summarize(data, label="🌐 Overall Dataset Summary")

    # Group by page_id
    page_groups = group_by(data, ["page_id"])
    for page_id, group in list(page_groups.items())[:5]:  # Limit to first 5 for display
        summarize(group, label=f"📁 Group Summary: page_id = {page_id[0]}")

    # Group by page_id and ad_id
    page_ad_groups = group_by(data, ["page_id", "ad_id"])
    for key in list(page_ad_groups.keys())[:5]:  # Limit to top 5 combos
        summarize(page_ad_groups[key], label=f"🔗 Group Summary: page_id = {key[0]}, ad_id = {key[1]}")
# Out:
# ============================================================
# 🌐 Overall Dataset Summary
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 4475
#     Most Frequent : '4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d' (55503 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 246745
#     Most Frequent : '0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 547
#     Most Frequent : '2024-10-27' (8619 times)
#
# 📝 bylines (Categorical)
#     Unique Values : 3786
#     Most Frequent : 'HARRIS FOR PRESIDENT' (49788 times)
#
# 📝 currency (Categorical)
#     Unique Values : 18
#     Most Frequent : 'USD' (246599 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 141122
#     Most Frequent : '{}' (30989 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 215622
#     Most Frequent : '{}' (30989 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 246745
#     Mean    : 556462.86
#     Min     : 0.0
#     Max     : 1000001.0
#     Std Dev : 409863.93
#
# 📊 estimated_impressions (Numeric)
#     Count   : 246745
#     Mean    : 45601.53
#     Min     : 499.0
#     Max     : 1000000.0
#     Std Dev : 136790.49
#
# 📊 estimated_spend (Numeric)
#     Count   : 246745
#     Mean    : 1061.29
#     Min     : 49.0
#     Max     : 474999.0
#     Std Dev : 4992.55
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 9
#     Most Frequent : '['facebook', 'instagram']' (214434 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 26338
#     Most Frequent : 'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855' (5972 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 278
#     Most Frequent : '[]' (73205 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.26
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.05
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.22
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.55
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.38
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.27
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.44
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.22
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.42
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.57
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.12
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.33
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.23
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.42
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.14
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.16
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.12
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.33
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.12
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.14
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.16
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.11
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.31
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.06
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.05
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.11
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.31
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.03
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.08
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.27
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.19
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.39
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.08
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 246745
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.05
#
#
# ============================================================
# 📁 Group Summary: page_id = 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230' (33 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 33
#     Most Frequent : '0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 5
#     Most Frequent : '2024-10-13' (13 times)
#
# 📝 bylines (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Texas Organizing Project PAC' (33 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (33 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 21
#     Most Frequent : '{'Texas': {'spend': 149, 'impressions': 17499}}' (4 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 31
#     Most Frequent : '{}' (3 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 33
#     Mean    : 43636.36
#     Min     : 30000.0
#     Max     : 75000.0
#     Std Dev : 20680.57
#
# 📊 estimated_impressions (Numeric)
#     Count   : 33
#     Mean    : 66908.09
#     Min     : 499.0
#     Max     : 374999.0
#     Std Dev : 95130.57
#
# 📊 estimated_spend (Numeric)
#     Count   : 33
#     Mean    : 467.18
#     Min     : 49.0
#     Max     : 2249.0
#     Std Dev : 652.94
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram']' (33 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 3
#     Most Frequent : 'dc522d5aa4f91c326d105ec4c482cf4b0c378161a6438a4c604061979c49f0dc' (14 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Kamala Harris', 'Tim Walz']' (33 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 33
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 33
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.42
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.42
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.42
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 33
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group Summary: page_id = b9eb7e353e596d5fc99568d4ef77d4b11ced3243537cbd0895dde3195b69b6be
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'b9eb7e353e596d5fc99568d4ef77d4b11ced3243537cbd0895dde3195b69b6be' (3 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 3
#     Most Frequent : 'c62978153c04116d88ead49379916855f2cb58bf788631f26f3f1fcb2962ad48' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 2
#     Most Frequent : '2024-11-02' (2 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (3 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 2
#     Most Frequent : '{}' (2 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 2
#     Most Frequent : '{}' (2 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 3
#     Mean    : 1000001.00
#     Min     : 1000001.0
#     Max     : 1000001.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 3
#     Mean    : 16165.67
#     Min     : 499.0
#     Max     : 47499.0
#     Std Dev : 22156.01
#
# 📊 estimated_spend (Numeric)
#     Count   : 3
#     Mean    : 82.33
#     Min     : 49.0
#     Max     : 149.0
#     Std Dev : 47.14
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram', 'audience_network', 'messenger']' (3 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 3
#     Most Frequent : '5ffb1d89916e779d01193e726cd8802b1952507da292bcf2c575cd9cc7b44cdb' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Tim Walz']' (3 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.33
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.47
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.67
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.47
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.67
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.47
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.33
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.47
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 3
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group Summary: page_id = 7167146d80bba9d877a246d9682c7eecf3cae7b63337cf8ec01fff2eff27c909
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '7167146d80bba9d877a246d9682c7eecf3cae7b63337cf8ec01fff2eff27c909' (7 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 7
#     Most Frequent : '8eef0db915699b38fa798d4d9f5d944b1fed68bb08cce48b287ede96c336db21' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 6
#     Most Frequent : '2024-11-02' (2 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (7 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 3
#     Most Frequent : '{'Minnesota': {'spend': 49, 'impressions': 499}}' (5 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 7
#     Most Frequent : '{}' (1 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 7
#     Mean    : 1000001.00
#     Min     : 1000001.0
#     Max     : 1000001.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 7
#     Mean    : 641.86
#     Min     : 499.0
#     Max     : 1499.0
#     Std Dev : 349.93
#
# 📊 estimated_spend (Numeric)
#     Count   : 7
#     Mean    : 49.00
#     Min     : 49.0
#     Max     : 49.0
#     Std Dev : 0.00
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram', 'audience_network']' (7 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 7
#     Most Frequent : '5ffb1d89916e779d01193e726cd8802b1952507da292bcf2c575cd9cc7b44cdb' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Tim Walz']' (7 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.14
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.29
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.45
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.29
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.45
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.43
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.43
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.14
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.14
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.14
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.14
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 7
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group Summary: page_id = 8109a1809ae54265da9ab4b69f5e7f6c3c42d013a07f643513875ebc1f73e8d3
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '8109a1809ae54265da9ab4b69f5e7f6c3c42d013a07f643513875ebc1f73e8d3' (1 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'cec88e0dc69463eca43511cefe95839e94cbdbff6abcaba18398663ea44b6292' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 1
#     Most Frequent : '2024-11-02' (1 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (1 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 1
#     Most Frequent : '{'Minnesota': {'spend': 49, 'impressions': 499}}' (1 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 1
#     Most Frequent : '{'male_18-24': {'spend': 2, 'impressions': 27}, 'female_25-34': {'spend': 1, 'impressions': 13}, 'male_25-34': {'spend': 0, 'impressions': 9}, 'female_35-44': {'spend': 0, 'impressions': 4}, 'male_35-44': {'spend': 2, 'impressions': 27}, 'female_45-54': {'spend': 2, 'impressions': 27}, 'male_45-54': {'spend': 6, 'impressions': 64}, 'female_55-64': {'spend': 4, 'impressions': 50}, 'male_55-64': {'spend': 6, 'impressions': 64}, 'female_65+': {'spend': 10, 'impressions': 109}, 'male_65+': {'spend': 9, 'impressions': 100}}' (1 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 1
#     Mean    : 30000.00
#     Min     : 30000.0
#     Max     : 30000.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 1
#     Mean    : 499.00
#     Min     : 499.0
#     Max     : 499.0
#     Std Dev : 0.00
#
# 📊 estimated_spend (Numeric)
#     Count   : 1
#     Mean    : 49.00
#     Min     : 49.0
#     Max     : 49.0
#     Std Dev : 0.00
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram', 'audience_network', 'messenger']' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '92ea6a7015d912f291b61df4d1b7d0c9685debc85f49b4f7abc11526abee6c76' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Tim Walz']' (1 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group Summary: page_id = bb8759172b28450769f79e10c63a64ae09b986a7eab109eefb3ddff8c39886ad
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'bb8759172b28450769f79e10c63a64ae09b986a7eab109eefb3ddff8c39886ad' (179 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 179
#     Most Frequent : '97ba12169373d6fc48fe898c0e9457fbd391868a704a0ef3fcc1d66aa29d7046' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 15
#     Most Frequent : '2024-10-14' (44 times)
#
# 📝 bylines (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Seminole County Democratic Executive Committee' (179 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (179 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 23
#     Most Frequent : '{'Florida': {'spend': 49, 'impressions': 499}}' (57 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 153
#     Most Frequent : '{}' (27 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 179
#     Mean    : 220055.87
#     Min     : 30000.0
#     Max     : 750000.0
#     Std Dev : 116176.26
#
# 📊 estimated_impressions (Numeric)
#     Count   : 179
#     Mean    : 6387.27
#     Min     : 499.0
#     Max     : 187499.0
#     Std Dev : 17018.76
#
# 📊 estimated_spend (Numeric)
#     Count   : 179
#     Mean    : 56.82
#     Min     : 49.0
#     Max     : 649.0
#     Std Dev : 51.19
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram']' (179 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 3
#     Most Frequent : 'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855' (176 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 5
#     Most Frequent : '['Kamala Harris']' (116 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.98
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.13
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 179
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group Summary: page_id = 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230, ad_id = 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230' (1 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 1
#     Most Frequent : '2024-10-21' (1 times)
#
# 📝 bylines (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Texas Organizing Project PAC' (1 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (1 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 1
#     Most Frequent : '{'Texas': {'spend': 249, 'impressions': 47499}}' (1 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 1
#     Most Frequent : '{'female_18-24': {'spend': 28, 'impressions': 5507}, 'male_45-54': {'spend': 14, 'impressions': 2757}, 'male_65+': {'spend': 3, 'impressions': 714}, 'female_65+': {'spend': 3, 'impressions': 725}, 'unknown_55-64': {'spend': 0, 'impressions': 21}, 'male_55-64': {'spend': 7, 'impressions': 1502}, 'female_55-64': {'spend': 7, 'impressions': 1520}, 'unknown_45-54': {'spend': 0, 'impressions': 40}, 'female_45-54': {'spend': 14, 'impressions': 2735}, 'male_18-24': {'spend': 21, 'impressions': 4055}, 'unknown_35-44': {'spend': 0, 'impressions': 69}, 'male_35-44': {'spend': 26, 'impressions': 5149}, 'female_35-44': {'spend': 28, 'impressions': 5528}, 'unknown_25-34': {'spend': 0, 'impressions': 91}, 'male_25-34': {'spend': 41, 'impressions': 7976}, 'female_25-34': {'spend': 46, 'impressions': 8920}, 'unknown_18-24': {'spend': 0, 'impressions': 171}, 'unknown_65+': {'spend': 0, 'impressions': 10}}' (1 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 1
#     Mean    : 30000.00
#     Min     : 30000.0
#     Max     : 30000.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 1
#     Mean    : 47499.00
#     Min     : 47499.0
#     Max     : 47499.0
#     Std Dev : 0.00
#
# 📊 estimated_spend (Numeric)
#     Count   : 1
#     Mean    : 249.00
#     Min     : 249.0
#     Max     : 249.0
#     Std Dev : 0.00
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram']' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '362d68d42e34e070bc9f999033642b8fddfca5404195fc27690c60e0acde1d5b' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Kamala Harris', 'Tim Walz']' (1 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group Summary: page_id = 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230, ad_id = 86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230' (1 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 1
#     Most Frequent : '2024-10-18' (1 times)
#
# 📝 bylines (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Texas Organizing Project PAC' (1 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (1 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 1
#     Most Frequent : '{'Texas': {'spend': 49, 'impressions': 22499}}' (1 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 1
#     Most Frequent : '{'female_18-24': {'spend': 8, 'impressions': 3904}, 'male_45-54': {'spend': 2, 'impressions': 1129}, 'male_65+': {'spend': 0, 'impressions': 299}, 'female_65+': {'spend': 0, 'impressions': 251}, 'unknown_55-64': {'spend': 0, 'impressions': 5}, 'male_55-64': {'spend': 1, 'impressions': 602}, 'female_55-64': {'spend': 0, 'impressions': 456}, 'unknown_45-54': {'spend': 0, 'impressions': 15}, 'female_45-54': {'spend': 1, 'impressions': 856}, 'male_18-24': {'spend': 6, 'impressions': 2922}, 'unknown_35-44': {'spend': 0, 'impressions': 23}, 'male_35-44': {'spend': 4, 'impressions': 2145}, 'female_35-44': {'spend': 3, 'impressions': 1726}, 'unknown_25-34': {'spend': 0, 'impressions': 31}, 'male_25-34': {'spend': 9, 'impressions': 4323}, 'female_25-34': {'spend': 8, 'impressions': 3744}, 'unknown_18-24': {'spend': 0, 'impressions': 53}, 'unknown_65+': {'spend': 0, 'impressions': 5}}' (1 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 1
#     Mean    : 75000.00
#     Min     : 75000.0
#     Max     : 75000.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 1
#     Mean    : 22499.00
#     Min     : 22499.0
#     Max     : 22499.0
#     Std Dev : 0.00
#
# 📊 estimated_spend (Numeric)
#     Count   : 1
#     Mean    : 49.00
#     Min     : 49.0
#     Max     : 49.0
#     Std Dev : 0.00
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram']' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'dc522d5aa4f91c326d105ec4c482cf4b0c378161a6438a4c604061979c49f0dc' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Kamala Harris', 'Tim Walz']' (1 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group Summary: page_id = 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230, ad_id = 07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230' (1 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 1
#     Most Frequent : '2024-10-13' (1 times)
#
# 📝 bylines (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Texas Organizing Project PAC' (1 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (1 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 1
#     Most Frequent : '{'Texas': {'spend': 149, 'impressions': 32499}}' (1 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 1
# ...
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 1
#     Mean    : 75000.00
#     Min     : 75000.0
#     Max     : 75000.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 1
#     Mean    : 32499.00
#     Min     : 32499.0
#     Max     : 32499.0
#     Std Dev : 0.00
#
# 📊 estimated_spend (Numeric)
#     Count   : 1
#     Mean    : 149.00
#     Min     : 149.0
#     Max     : 149.0
#     Std Dev : 0.00
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram']' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '6dc61896f4a44cf4fdbe564604bbebe33b84d2dbfb8bacc761b345b2879f0804' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Kamala Harris', 'Tim Walz']' (1 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group Summary: page_id = b9eb7e353e596d5fc99568d4ef77d4b11ced3243537cbd0895dde3195b69b6be, ad_id = c62978153c04116d88ead49379916855f2cb58bf788631f26f3f1fcb2962ad48
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'b9eb7e353e596d5fc99568d4ef77d4b11ced3243537cbd0895dde3195b69b6be' (1 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'c62978153c04116d88ead49379916855f2cb58bf788631f26f3f1fcb2962ad48' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 1
#     Most Frequent : '2024-11-02' (1 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (1 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 1
#     Most Frequent : '{}' (1 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 1
#     Most Frequent : '{}' (1 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 1
#     Mean    : 1000001.00
#     Min     : 1000001.0
#     Max     : 1000001.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 1
#     Mean    : 499.00
#     Min     : 499.0
#     Max     : 499.0
#     Std Dev : 0.00
#
# 📊 estimated_spend (Numeric)
#     Count   : 1
#     Mean    : 49.00
#     Min     : 49.0
#     Max     : 49.0
#     Std Dev : 0.00
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram', 'audience_network', 'messenger']' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '5ffb1d89916e779d01193e726cd8802b1952507da292bcf2c575cd9cc7b44cdb' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Tim Walz']' (1 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group Summary: page_id = b9eb7e353e596d5fc99568d4ef77d4b11ced3243537cbd0895dde3195b69b6be, ad_id = 785e91ef18a5794565af03a6df4e7077fe1d915bfb34025019f3d42f43fcf9e8
# ============================================================
#
# 📝 page_id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'b9eb7e353e596d5fc99568d4ef77d4b11ced3243537cbd0895dde3195b69b6be' (1 times)
#
# 📝 ad_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '785e91ef18a5794565af03a6df4e7077fe1d915bfb34025019f3d42f43fcf9e8' (1 times)
#
# 📝 ad_creation_time (Categorical)
#     Unique Values : 1
#     Most Frequent : '2024-11-02' (1 times)
#
# 📝 currency (Categorical)
#     Unique Values : 1
#     Most Frequent : 'USD' (1 times)
#
# 📝 delivery_by_region (Categorical)
#     Unique Values : 1
#     Most Frequent : '{}' (1 times)
#
# 📝 demographic_distribution (Categorical)
#     Unique Values : 1
#     Most Frequent : '{}' (1 times)
#
# 📊 estimated_audience_size (Numeric)
#     Count   : 1
#     Mean    : 1000001.00
#     Min     : 1000001.0
#     Max     : 1000001.0
#     Std Dev : 0.00
#
# 📊 estimated_impressions (Numeric)
#     Count   : 1
#     Mean    : 499.00
#     Min     : 499.0
#     Max     : 499.0
#     Std Dev : 0.00
#
# 📊 estimated_spend (Numeric)
#     Count   : 1
#     Mean    : 49.00
#     Min     : 49.0
#     Max     : 49.0
#     Std Dev : 0.00
#
# 📝 publisher_platforms (Categorical)
#     Unique Values : 1
#     Most Frequent : '['facebook', 'instagram', 'audience_network', 'messenger']' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'b7360494f7dd93ffa2320d88b10a5810a5835d15839aebea88846e9c54eef9e0' (1 times)
#
# 📝 illuminating_mentions (Categorical)
#     Unique Values : 1
#     Most Frequent : '['Tim Walz']' (1 times)
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
