# %%
import csv
import math
from collections import defaultdict, Counter

FILE_PATH = "2024_tw_posts_president_scored_anon.csv"

def is_number(s):
    try:
        float(s.replace(",", ""))
        return True
    except:
        return False

def to_number(s):
    try:
        return float(s.replace(",", ""))
    except:
        return None

def mean(lst):
    return sum(lst) / len(lst) if lst else 0

def std_dev(lst):
    if len(lst) < 2:
        return 0
    avg = mean(lst)
    return math.sqrt(sum((x - avg) ** 2 for x in lst) / len(lst))

def read_csv(file_path):
    with open(file_path, mode="r", encoding="utf-8") as f:
        return list(csv.DictReader(f))

def summarize(data, label="Overall Summary"):
    print(f"\n{'=' * 60}")
    print(f"{label}")
    print(f"{'=' * 60}")

    if not data:
        print("No data found.\n")
        return

    columns = data[0].keys()
    for col in columns:
        values = [row[col].strip() for row in data if row[col].strip()]
        numeric_vals = [to_number(v) for v in values if is_number(v)]

        if numeric_vals:
            print(f"\n📊 {col} (Numeric)")
            print(f"    Count   : {len(numeric_vals)}")
            print(f"    Mean    : {mean(numeric_vals):.2f}")
            print(f"    Min     : {min(numeric_vals)}")
            print(f"    Max     : {max(numeric_vals)}")
            print(f"    Std Dev : {std_dev(numeric_vals):.2f}")
        elif values:
            counter = Counter(values)
            most_common = counter.most_common(1)[0] if counter else ("N/A", 0)
            print(f"\n📝 {col} (Categorical)")
            print(f"    Unique Values : {len(counter)}")
            print(f"    Most Frequent : '{most_common[0]}' ({most_common[1]} times)")
    print()

def group_by(data, keys):
    grouped = defaultdict(list)
    for row in data:
        key = tuple(row[k] for k in keys)
        grouped[key].append(row)
    return grouped

if __name__ == "__main__":
    data = read_csv(FILE_PATH)

    # Overall
    summarize(data, label="🌐 Overall Twitter Dataset Summary")

    # Grouped by id (top 5)
    id_groups = group_by(data, ["id"])
    for key in list(id_groups.keys())[:5]:
        summarize(id_groups[key], label=f"📁 Group: id = {key[0]}")

    # Grouped by id and quoteId (top 5)
    id_quote_groups = group_by(data, ["id", "quoteId"])
    for key in list(id_quote_groups.keys())[:5]:
        summarize(id_quote_groups[key], label=f"🔗 Group: id = {key[0]}, quoteId = {key[1]}")
# Out:
# ============================================================
# 🌐 Overall Twitter Dataset Summary
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 27304
#     Most Frequent : 'cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 27304
#     Most Frequent : 'f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 14
#     Most Frequent : 'Twitter Web App' (14930 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 27304
#     Mean    : 1322.06
#     Min     : 0.0
#     Max     : 144615.0
#     Std Dev : 3404.94
#
# 📊 replyCount (Numeric)
#     Count   : 27304
#     Mean    : 1063.79
#     Min     : 0.0
#     Max     : 121270.0
#     Std Dev : 3174.92
#
# 📊 likeCount (Numeric)
#     Count   : 27304
#     Mean    : 6913.69
#     Min     : 0.0
#     Max     : 915221.0
#     Std Dev : 21589.91
#
# 📊 quoteCount (Numeric)
#     Count   : 27304
#     Mean    : 128.08
#     Min     : 0.0
#     Max     : 123320.0
#     Std Dev : 1131.51
#
# 📊 viewCount (Numeric)
#     Count   : 27304
#     Mean    : 507084.73
#     Min     : 5.0
#     Max     : 333502775.0
#     Std Dev : 3212115.16
#
# 📝 createdAt (Categorical)
#     Unique Values : 27014
#     Most Frequent : '2023-10-06 04:55:21' (4 times)
#
# 📝 lang (Categorical)
#     Unique Values : 12
#     Most Frequent : 'en' (27281 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 27304
#     Mean    : 136.21
#     Min     : 0.0
#     Max     : 42693.0
#     Std Dev : 712.57
#
# 📝 isReply (Categorical)
#     Unique Values : 2
#     Most Frequent : 'False' (23930 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (27304 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 2
#     Most Frequent : 'False' (24064 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 2
#     Most Frequent : 'False' (27296 times)
#
# 📊 quoteId (Numeric)
#     Count   : 3287
#     Mean    : 1764298396658922752.00
#     Min     : 7.912639390153769e+17
#     Max     : 1.8535761683325583e+18
#     Std Dev : 68936377884959352.00
#
# 📊 inReplyToId (Numeric)
#     Count   : 3345
#     Mean    : 1758285724741985792.00
#     Min     : 1.2400673584227e+18
#     Max     : 1.853530653414859e+18
#     Std Dev : 43605446235839016.00
#
# 📝 month_year (Categorical)
#     Unique Values : 15
#     Most Frequent : '2024-10' (3586 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 27136
#     Most Frequent : '36cb7d55fcf85362ca03f624c2f574f1f55f89db559b17da084df6e643afe5cd' (21 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.04
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.19
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.56
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.51
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.31
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.46
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.23
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.42
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.11
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.31
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.25
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.09
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.13
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.09
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.16
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.37
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.13
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.17
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.04
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.20
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.15
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.23
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.25
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.06
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.10
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.12
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.04
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.19
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.05
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.22
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.05
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.15
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.18
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.38
#
# 📊 scam_illuminating (Numeric)
#     Count   : 26034
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 27304
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.04
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 27304
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.05
#
#
# ============================================================
# 📁 Group: id = cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 10.00
#     Min     : 10.0
#     Max     : 10.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 37.00
#     Min     : 37.0
#     Max     : 37.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 94.00
#     Min     : 94.0
#     Max     : 94.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 2.00
#     Min     : 2.0
#     Max     : 2.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 15610.00
#     Min     : 15610.0
#     Max     : 15610.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-30 14:11:00' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '1876a8ce2704af06f47f4cf6c5bcadcda90ca7b2d03e0ca069a8c5eb7af4c983' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group: id = 0e3db0c35a290c6df3b737d15882846c108cc80a9b7e5ca64a0129d4e3cd3ad7
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : '0e3db0c35a290c6df3b737d15882846c108cc80a9b7e5ca64a0129d4e3cd3ad7' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a1962f54943732a0dc006c33b4b6f5764c7085a1282a59439b891ee0eb59a0dc' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 421.00
#     Min     : 421.0
#     Max     : 421.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 1005.00
#     Min     : 1005.0
#     Max     : 1005.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 2697.00
#     Min     : 2697.0
#     Max     : 2697.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 60.00
#     Min     : 60.0
#     Max     : 60.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 158324.00
#     Min     : 158324.0
#     Max     : 158324.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-29 13:27:24' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 13.00
#     Min     : 13.0
#     Max     : 13.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'ca5cbace947a7eaae06ef2d2423ff68788e52e76043d5a4bb569a1653707700a' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group: id = 256905919085d2946d5d187abc6cbe81a8abe3384793b362fa6aa4144bf42776
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : '256905919085d2946d5d187abc6cbe81a8abe3384793b362fa6aa4144bf42776' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : '4ddbbdb7f4d8ef62fccf3ed20c993bb665b8620fedb089e81b43c0c7bc0c613e' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 39.00
#     Min     : 39.0
#     Max     : 39.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 194.00
#     Min     : 194.0
#     Max     : 194.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 332.00
#     Min     : 332.0
#     Max     : 332.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 12.00
#     Min     : 12.0
#     Max     : 12.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 35535.00
#     Min     : 35535.0
#     Max     : 35535.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-27 20:31:23' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'ac5132800ac8301dd96b6502706c0afad8b483d6d0fdc49e13916621c4adfce8' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group: id = a461b32b31e72b222df7fdda0a8e68b0092e31deda33a8652eb443459546a4c4
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a461b32b31e72b222df7fdda0a8e68b0092e31deda33a8652eb443459546a4c4' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'c7e729c427e714baf06d88a2856a1be07d4ff52e1e633412ce15b0160e8f6c38' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 47.00
#     Min     : 47.0
#     Max     : 47.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 332.00
#     Min     : 332.0
#     Max     : 332.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 427.00
#     Min     : 427.0
#     Max     : 427.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 62.00
#     Min     : 62.0
#     Max     : 62.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 199642.00
#     Min     : 199642.0
#     Max     : 199642.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-26 01:52:40' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 7.00
#     Min     : 7.0
#     Max     : 7.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'b12b8365f96e4ce77fc72599ac977a06fb329e86c2fe839a7350ac649c306d68' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group: id = ca2795ec79d62adc1fff06c4d3bc9da0bbc899e32c9b218798ac62a0ceae19dc
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'ca2795ec79d62adc1fff06c4d3bc9da0bbc899e32c9b218798ac62a0ceae19dc' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'c589bd751d7e1d275901b184087716d3155a582b16430810211e1344d3ad2785' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter Web App' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 17.00
#     Min     : 17.0
#     Max     : 17.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 46.00
#     Min     : 46.0
#     Max     : 46.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 106.00
#     Min     : 106.0
#     Max     : 106.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 3.00
#     Min     : 3.0
#     Max     : 3.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 17917.00
#     Min     : 17917.0
#     Max     : 17917.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-21 13:24:13' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 2.00
#     Min     : 2.0
#     Max     : 2.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '58788e34f34d8a3f530dd68d9faf79b2add251dc9a76e0e9ae927483ddd46afb' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: id = cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d, quoteId =
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 10.00
#     Min     : 10.0
#     Max     : 10.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 37.00
#     Min     : 37.0
#     Max     : 37.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 94.00
#     Min     : 94.0
#     Max     : 94.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 2.00
#     Min     : 2.0
#     Max     : 2.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 15610.00
#     Min     : 15610.0
#     Max     : 15610.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-30 14:11:00' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '1876a8ce2704af06f47f4cf6c5bcadcda90ca7b2d03e0ca069a8c5eb7af4c983' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: id = 0e3db0c35a290c6df3b737d15882846c108cc80a9b7e5ca64a0129d4e3cd3ad7, quoteId =
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : '0e3db0c35a290c6df3b737d15882846c108cc80a9b7e5ca64a0129d4e3cd3ad7' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a1962f54943732a0dc006c33b4b6f5764c7085a1282a59439b891ee0eb59a0dc' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 421.00
#     Min     : 421.0
#     Max     : 421.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 1005.00
#     Min     : 1005.0
#     Max     : 1005.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 2697.00
#     Min     : 2697.0
#     Max     : 2697.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 60.00
#     Min     : 60.0
#     Max     : 60.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 158324.00
#     Min     : 158324.0
#     Max     : 158324.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-29 13:27:24' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 13.00
#     Min     : 13.0
#     Max     : 13.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'ca5cbace947a7eaae06ef2d2423ff68788e52e76043d5a4bb569a1653707700a' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: id = 256905919085d2946d5d187abc6cbe81a8abe3384793b362fa6aa4144bf42776, quoteId =
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : '256905919085d2946d5d187abc6cbe81a8abe3384793b362fa6aa4144bf42776' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : '4ddbbdb7f4d8ef62fccf3ed20c993bb665b8620fedb089e81b43c0c7bc0c613e' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 39.00
#     Min     : 39.0
#     Max     : 39.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 194.00
#     Min     : 194.0
#     Max     : 194.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 332.00
#     Min     : 332.0
#     Max     : 332.0
# ...
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'ac5132800ac8301dd96b6502706c0afad8b483d6d0fdc49e13916621c4adfce8' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: id = a461b32b31e72b222df7fdda0a8e68b0092e31deda33a8652eb443459546a4c4, quoteId =
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a461b32b31e72b222df7fdda0a8e68b0092e31deda33a8652eb443459546a4c4' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'c7e729c427e714baf06d88a2856a1be07d4ff52e1e633412ce15b0160e8f6c38' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter for iPhone' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 47.00
#     Min     : 47.0
#     Max     : 47.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 332.00
#     Min     : 332.0
#     Max     : 332.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 427.00
#     Min     : 427.0
#     Max     : 427.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 62.00
#     Min     : 62.0
#     Max     : 62.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 199642.00
#     Min     : 199642.0
#     Max     : 199642.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-26 01:52:40' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 7.00
#     Min     : 7.0
#     Max     : 7.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : 'b12b8365f96e4ce77fc72599ac977a06fb329e86c2fe839a7350ac649c306d68' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: id = ca2795ec79d62adc1fff06c4d3bc9da0bbc899e32c9b218798ac62a0ceae19dc, quoteId =
# ============================================================
#
# 📝 id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'ca2795ec79d62adc1fff06c4d3bc9da0bbc899e32c9b218798ac62a0ceae19dc' (1 times)
#
# 📝 url (Categorical)
#     Unique Values : 1
#     Most Frequent : 'c589bd751d7e1d275901b184087716d3155a582b16430810211e1344d3ad2785' (1 times)
#
# 📝 source (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Twitter Web App' (1 times)
#
# 📊 retweetCount (Numeric)
#     Count   : 1
#     Mean    : 17.00
#     Min     : 17.0
#     Max     : 17.0
#     Std Dev : 0.00
#
# 📊 replyCount (Numeric)
#     Count   : 1
#     Mean    : 46.00
#     Min     : 46.0
#     Max     : 46.0
#     Std Dev : 0.00
#
# 📊 likeCount (Numeric)
#     Count   : 1
#     Mean    : 106.00
#     Min     : 106.0
#     Max     : 106.0
#     Std Dev : 0.00
#
# 📊 quoteCount (Numeric)
#     Count   : 1
#     Mean    : 3.00
#     Min     : 3.0
#     Max     : 3.0
#     Std Dev : 0.00
#
# 📊 viewCount (Numeric)
#     Count   : 1
#     Mean    : 17917.00
#     Min     : 17917.0
#     Max     : 17917.0
#     Std Dev : 0.00
#
# 📝 createdAt (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-21 13:24:13' (1 times)
#
# 📝 lang (Categorical)
#     Unique Values : 1
#     Most Frequent : 'en' (1 times)
#
# 📊 bookmarkCount (Numeric)
#     Count   : 1
#     Mean    : 2.00
#     Min     : 2.0
#     Max     : 2.0
#     Std Dev : 0.00
#
# 📝 isReply (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isRetweet (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isQuote (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 isConversationControlled (Categorical)
#     Unique Values : 1
#     Most Frequent : 'False' (1 times)
#
# 📝 month_year (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09' (1 times)
#
# 📝 illuminating_scored_message (Categorical)
#     Unique Values : 1
#     Most Frequent : '58788e34f34d8a3f530dd68d9faf79b2add251dc9a76e0e9ae927483ddd46afb' (1 times)
#
# 📊 election_integrity_Truth_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
