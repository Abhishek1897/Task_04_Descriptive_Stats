# %%
import csv
import math
from collections import defaultdict, Counter

FILE_PATH = "2024_fb_posts_president_scored_anon.csv"

def is_number(s):
    try:
        float(s.replace(",", ""))  # remove commas from numbers
        return True
    except:
        return False

def to_number(s):
    try:
        return float(s.replace(",", ""))
    except:
        return None

def mean(lst):
    return sum(lst) / len(lst) if lst else 0

def std_dev(lst):
    if len(lst) < 2:
        return 0
    avg = mean(lst)
    variance = sum((x - avg) ** 2 for x in lst) / len(lst)
    return math.sqrt(variance)

def read_csv(file_path):
    with open(file_path, mode="r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        return list(reader)

def summarize(data, label="Overall Summary"):
    print(f"\n{'=' * 60}")
    print(f"{label}")
    print(f"{'=' * 60}")

    if not data:
        print("No data found in this group.\n")
        return

    columns = data[0].keys()
    for col in columns:
        values = [row[col].strip() for row in data if row[col].strip()]
        numeric_vals = [to_number(v) for v in values if is_number(v)]

        if numeric_vals:
            print(f"\n📊 {col} (Numeric)")
            print(f"    Count   : {len(numeric_vals)}")
            print(f"    Mean    : {mean(numeric_vals):.2f}")
            print(f"    Min     : {min(numeric_vals)}")
            print(f"    Max     : {max(numeric_vals)}")
            print(f"    Std Dev : {std_dev(numeric_vals):.2f}")
        elif values:
            counter = Counter(values)
            most_common = counter.most_common(1)[0]
            print(f"\n📝 {col} (Categorical)")
            print(f"    Unique Values : {len(counter)}")
            print(f"    Most Frequent : '{most_common[0]}' ({most_common[1]} times)")
    print()

def group_by(data, keys):
    groups = defaultdict(list)
    for row in data:
        key = tuple(row[k] for k in keys)
        groups[key].append(row)
    return groups

if __name__ == "__main__":
    data = read_csv(FILE_PATH)

    # Overall stats
    summarize(data, label="🌐 Overall Facebook Posts Summary")

    # Grouped by Facebook_Id (top 5)
    fb_groups = group_by(data, ["Facebook_Id"])
    for key in list(fb_groups.keys())[:5]:
        summarize(fb_groups[key], label=f"📁 Group: Facebook_Id = {key[0]}")

    # Grouped by Facebook_Id and post_id (top 5)
    fb_post_groups = group_by(data, ["Facebook_Id", "post_id"])
    for key in list(fb_post_groups.keys())[:5]:
        summarize(fb_post_groups[key], label=f"🔗 Group: Facebook_Id = {key[0]}, post_id = {key[1]}")
# Out:
# ============================================================
# 🌐 Overall Facebook Posts Summary
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 21
#     Most Frequent : '32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064' (9013 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 19009
#     Most Frequent : '8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 6
#     Most Frequent : 'PERSON' (9453 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (16280 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 18951
#     Most Frequent : '2023-11-14 11:11:44 EST' (2 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 425
#     Most Frequent : '2024-10-31' (103 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 16102
#     Most Frequent : '19:42:00' (7 times)
#
# 📝 Type (Categorical)
#     Unique Values : 9
#     Most Frequent : 'Link' (7404 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 19009
#     Mean    : 4190.44
#     Min     : 0.0
#     Max     : 696853.0
#     Std Dev : 19002.58
#
# 📊 Likes (Numeric)
#     Count   : 19009
#     Mean    : 2377.70
#     Min     : 0.0
#     Max     : 351979.0
#     Std Dev : 11253.17
#
# 📊 Comments (Numeric)
#     Count   : 19009
#     Mean    : 901.58
#     Min     : 0.0
#     Max     : 93872.0
#     Std Dev : 3681.88
#
# 📊 Shares (Numeric)
#     Count   : 19009
#     Mean    : 320.54
#     Min     : 0.0
#     Max     : 76150.0
#     Std Dev : 1722.11
#
# 📊 Love (Numeric)
#     Count   : 19009
#     Mean    : 413.88
#     Min     : 0.0
#     Max     : 244482.0
#     Std Dev : 3730.84
#
# 📊 Wow (Numeric)
#     Count   : 19009
#     Mean    : 5.87
#     Min     : 0.0
#     Max     : 4345.0
#     Std Dev : 52.95
#
# 📊 Haha (Numeric)
#     Count   : 19009
#     Mean    : 105.72
#     Min     : 0.0
#     Max     : 99276.0
#     Std Dev : 942.01
#
# 📊 Sad (Numeric)
#     Count   : 19009
#     Mean    : 10.17
#     Min     : 0.0
#     Max     : 56111.0
#     Std Dev : 418.31
#
# 📊 Angry (Numeric)
#     Count   : 19009
#     Mean    : 20.06
#     Min     : 0.0
#     Max     : 11814.0
#     Std Dev : 156.02
#
# 📊 Care (Numeric)
#     Count   : 19009
#     Mean    : 34.93
#     Min     : 0.0
#     Max     : 85236.0
#     Std Dev : 790.08
#
# 📝 Video Share Status (Categorical)
#     Unique Values : 3
#     Most Frequent : 'owned' (3100 times)
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 3
#     Most Frequent : '-' (13280 times)
#
# 📊 Post Views (Numeric)
#     Count   : 16544
#     Mean    : 6485.06
#     Min     : 0.0
#     Max     : 4276477.0
#     Std Dev : 90390.23
#
# 📊 Total Views (Numeric)
#     Count   : 16544
#     Mean    : 7461.85
#     Min     : 0.0
#     Max     : 4462155.0
#     Std Dev : 95973.38
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 16544
#     Mean    : 3555.94
#     Min     : 0.0
#     Max     : 4499458.0
#     Std Dev : 88091.39
#
# 📝 Video Length (Categorical)
#     Unique Values : 774
#     Most Frequent : '00:00:30' (83 times)
#
# 📊 Overperforming Score (Numeric)
#     Count   : 16544
#     Mean    : -2.74
#     Min     : -198.75
#     Max     : 246.78
#     Std Dev : 7.81
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.55
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.46
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.22
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.41
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.15
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.36
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.13
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.34
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.09
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.29
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.13
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.15
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.05
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.22
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.09
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.29
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.12
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.15
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.04
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.19
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.17
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.05
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.22
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.04
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.20
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.06
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.15
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.24
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.05
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.16
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.13
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.33
#
# 📊 scam_illuminating (Numeric)
#     Count   : 18060
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.14
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.05
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 19009
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.09
#
#
# ============================================================
# 📁 Group: Facebook_Id = a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813' (29 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 29
#     Most Frequent : '8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'PERSON' (29 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (29 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 29
#     Most Frequent : '2023-09-04 19:31:16 EDT' (1 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 21
#     Most Frequent : '2024-01-11' (3 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 29
#     Most Frequent : '19:31:16' (1 times)
#
# 📝 Type (Categorical)
#     Unique Values : 5
#     Most Frequent : 'Photo' (18 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 29
#     Mean    : 115.52
#     Min     : 29.0
#     Max     : 454.0
#     Std Dev : 94.55
#
# 📊 Likes (Numeric)
#     Count   : 29
#     Mean    : 50.45
#     Min     : 12.0
#     Max     : 104.0
#     Std Dev : 23.90
#
# 📊 Comments (Numeric)
#     Count   : 29
#     Mean    : 46.79
#     Min     : 5.0
#     Max     : 329.0
#     Std Dev : 68.42
#
# 📊 Shares (Numeric)
#     Count   : 29
#     Mean    : 3.59
#     Min     : 0.0
#     Max     : 15.0
#     Std Dev : 3.34
#
# 📊 Love (Numeric)
#     Count   : 29
#     Mean    : 4.07
#     Min     : 0.0
#     Max     : 17.0
#     Std Dev : 4.32
#
# 📊 Wow (Numeric)
#     Count   : 29
#     Mean    : 0.24
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.43
#
# 📊 Haha (Numeric)
#     Count   : 29
#     Mean    : 8.14
#     Min     : 1.0
#     Max     : 36.0
#     Std Dev : 7.16
#
# 📊 Sad (Numeric)
#     Count   : 29
#     Mean    : 0.55
#     Min     : 0.0
#     Max     : 12.0
#     Std Dev : 2.19
#
# 📊 Angry (Numeric)
#     Count   : 29
#     Mean    : 0.48
#     Min     : 0.0
#     Max     : 2.0
#     Std Dev : 0.62
#
# 📊 Care (Numeric)
#     Count   : 29
#     Mean    : 1.21
#     Min     : 0.0
#     Max     : 12.0
#     Std Dev : 2.93
#
# 📝 Video Share Status (Categorical)
#     Unique Values : 1
#     Most Frequent : 'owned' (1 times)
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 2
#     Most Frequent : '-' (28 times)
#
# 📊 Post Views (Numeric)
#     Count   : 29
#     Mean    : 59.17
#     Min     : 0.0
#     Max     : 1716.0
#     Std Dev : 313.11
#
# 📊 Total Views (Numeric)
#     Count   : 29
#     Mean    : 59.97
#     Min     : 0.0
#     Max     : 1739.0
#     Std Dev : 317.31
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📝 Video Length (Categorical)
#     Unique Values : 1
#     Most Frequent : '00:40:39' (1 times)
#
# 📊 Overperforming Score (Numeric)
#     Count   : 29
#     Mean    : -0.68
#     Min     : -3.35
#     Max     : 3.98
#     Std Dev : 1.78
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.55
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.31
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.46
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.17
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.38
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.14
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.34
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.62
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.41
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.10
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.30
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.25
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.25
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.25
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.18
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.10
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.30
#
# 📊 scam_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 29
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group: Facebook_Id = 7ec2cb4abf8effe3d91de57944c56b938b4f33059a6e33dfe23b549cf229989a
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : '7ec2cb4abf8effe3d91de57944c56b938b4f33059a6e33dfe23b549cf229989a' (616 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 616
#     Most Frequent : 'b83adc0e8ac0aedd39f55b72d723729e114a83d41fd48b1b13c7ec782c9a0649' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'POLITICAL_CANDIDATE' (358 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (358 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 597
#     Most Frequent : '2024-10-31T23:04:19.000Z' (2 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 225
#     Most Frequent : '2024-10-31' (26 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 595
#     Most Frequent : '14:29:37' (2 times)
#
# 📝 Type (Categorical)
#     Unique Values : 7
#     Most Frequent : 'Photo' (176 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 616
#     Mean    : 67984.82
#     Min     : 949.0
#     Max     : 696853.0
#     Std Dev : 73543.89
#
# 📊 Likes (Numeric)
#     Count   : 616
#     Mean    : 39394.85
#     Min     : 492.0
#     Max     : 351979.0
#     Std Dev : 43499.33
#
# 📊 Comments (Numeric)
#     Count   : 616
#     Mean    : 13920.44
#     Min     : 204.0
#     Max     : 93872.0
#     Std Dev : 13614.18
#
# 📊 Shares (Numeric)
#     Count   : 616
#     Mean    : 4835.73
#     Min     : 54.0
#     Max     : 69813.0
#     Std Dev : 6449.81
#
# 📊 Love (Numeric)
#     Count   : 616
#     Mean    : 8089.59
#     Min     : 0.0
#     Max     : 244482.0
#     Std Dev : 18484.54
#
# 📊 Wow (Numeric)
#     Count   : 616
#     Mean    : 54.68
#     Min     : 0.0
#     Max     : 4345.0
#     Std Dev : 209.04
#
# 📊 Haha (Numeric)
#     Count   : 616
#     Mean    : 887.20
#     Min     : 0.0
#     Max     : 99276.0
#     Std Dev : 4568.15
#
# 📊 Sad (Numeric)
#     Count   : 616
#     Mean    : 149.08
#     Min     : 0.0
#     Max     : 56111.0
#     Std Dev : 2278.24
#
# 📊 Angry (Numeric)
#     Count   : 616
#     Mean    : 144.05
#     Min     : 0.0
#     Max     : 11814.0
#     Std Dev : 682.12
#
# 📊 Care (Numeric)
#     Count   : 616
#     Mean    : 509.19
#     Min     : 0.0
#     Max     : 85236.0
#     Std Dev : 3581.22
#
# 📝 Video Share Status (Categorical)
#     Unique Values : 3
#     Most Frequent : 'crosspost' (63 times)
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 3
#     Most Frequent : '-' (222 times)
#
# 📊 Post Views (Numeric)
#     Count   : 358
#     Mean    : 172083.20
#     Min     : 0.0
#     Max     : 4276477.0
#     Std Dev : 542676.16
#
# 📊 Total Views (Numeric)
#     Count   : 358
#     Mean    : 186387.58
#     Min     : 0.0
#     Max     : 4462155.0
#     Std Dev : 567533.77
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 358
#     Mean    : 163542.49
#     Min     : 0.0
#     Max     : 4499458.0
#     Std Dev : 576538.46
#
# 📝 Video Length (Categorical)
#     Unique Values : 126
#     Most Frequent : '00:00:22' (3 times)
#
# 📊 Overperforming Score (Numeric)
#     Count   : 358
#     Mean    : -2.31
#     Min     : -15.95
#     Max     : 8.73
#     Std Dev : 3.64
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.24
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.43
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.11
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.31
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.25
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.23
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.33
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.47
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.18
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.39
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.12
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.33
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.30
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.46
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.13
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.06
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.04
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.09
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.04
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.13
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.08
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.08
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.04
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.24
#
# 📊 scam_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.17
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 616
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.04
#
#
# ============================================================
# 📁 Group: Facebook_Id = 058bd86861262fa71733f8515c34b729d9ebcad3d318e2a133a6c572dd80ba0b
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : '058bd86861262fa71733f8515c34b729d9ebcad3d318e2a133a6c572dd80ba0b' (210 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 210
#     Most Frequent : '1cea6a3ba6e5e032de0f6246ffcdcaa03cb620fe01787b14c00d5b67379b4142' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'POLITICIAN' (210 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (210 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 210
#     Most Frequent : '2023-09-30 18:15:44 EDT' (1 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 123
#     Most Frequent : '2023-09-28' (5 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 206
#     Most Frequent : '17:00:01' (3 times)
#
# 📝 Type (Categorical)
#     Unique Values : 4
#     Most Frequent : 'Photo' (91 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 210
#     Mean    : 105.73
#     Min     : 11.0
#     Max     : 920.0
#     Std Dev : 127.47
#
# 📊 Likes (Numeric)
#     Count   : 210
#     Mean    : 59.05
#     Min     : 5.0
#     Max     : 551.0
#     Std Dev : 78.56
#
# 📊 Comments (Numeric)
#     Count   : 210
#     Mean    : 26.34
#     Min     : 0.0
#     Max     : 425.0
#     Std Dev : 42.76
#
# 📊 Shares (Numeric)
#     Count   : 210
#     Mean    : 5.30
#     Min     : 0.0
#     Max     : 73.0
#     Std Dev : 6.91
#
# 📊 Love (Numeric)
#     Count   : 210
#     Mean    : 5.09
#     Min     : 0.0
#     Max     : 71.0
#     Std Dev : 8.84
#
# 📊 Wow (Numeric)
#     Count   : 210
#     Mean    : 0.22
#     Min     : 0.0
#     Max     : 4.0
#     Std Dev : 0.55
#
# 📊 Haha (Numeric)
#     Count   : 210
#     Mean    : 7.17
#     Min     : 0.0
#     Max     : 134.0
#     Std Dev : 14.54
#
# 📊 Sad (Numeric)
#     Count   : 210
#     Mean    : 0.62
#     Min     : 0.0
#     Max     : 40.0
#     Std Dev : 3.01
#
# 📊 Angry (Numeric)
#     Count   : 210
#     Mean    : 0.92
#     Min     : 0.0
#     Max     : 14.0
#     Std Dev : 2.12
#
# 📊 Care (Numeric)
#     Count   : 210
#     Mean    : 1.02
#     Min     : 0.0
#     Max     : 71.0
#     Std Dev : 5.54
#
# 📝 Video Share Status (Categorical)
#     Unique Values : 2
#     Most Frequent : 'owned' (66 times)
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 3
#     Most Frequent : '-' (143 times)
#
# 📊 Post Views (Numeric)
#     Count   : 210
#     Mean    : 251.94
#     Min     : 0.0
#     Max     : 17218.0
#     Std Dev : 1258.16
#
# 📊 Total Views (Numeric)
#     Count   : 210
#     Mean    : 279.76
#     Min     : 0.0
#     Max     : 17606.0
#     Std Dev : 1304.18
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📝 Video Length (Categorical)
#     Unique Values : 47
#     Most Frequent : '00:00:45' (4 times)
#
# 📊 Overperforming Score (Numeric)
#     Count   : 210
#     Mean    : -0.56
#     Min     : -5.73
#     Max     : 7.36
#     Std Dev : 2.20
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.59
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.56
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.29
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.45
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.17
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.38
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.15
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.36
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.11
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.32
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.21
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.41
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.14
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.26
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.10
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.29
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.17
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.03
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.17
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.24
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.12
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.04
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.20
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.18
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.38
#
# 📊 scam_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.10
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 210
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group: Facebook_Id = ac24f31c4d4b3d5555065fa9558bdca4ab4b5e1379922875ae9e6e32f1d46d25
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'ac24f31c4d4b3d5555065fa9558bdca4ab4b5e1379922875ae9e6e32f1d46d25' (1231 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 1231
#     Most Frequent : '02f1e0da0afc5706a26f18176c199bb1e4cadcee8b4e2b6d25fea650115e0a89' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'POLITICIAN' (867 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (867 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 1231
#     Most Frequent : '2023-09-02 11:27:00 EDT' (1 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 340
#     Most Frequent : '2024-10-30' (41 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 1134
#     Most Frequent : '10:15:02' (5 times)
#
# 📝 Type (Categorical)
#     Unique Values : 6
#     Most Frequent : 'Photo' (401 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 1231
#     Mean    : 8226.28
#     Min     : 96.0
#     Max     : 152355.0
#     Std Dev : 14040.90
#
# 📊 Likes (Numeric)
#     Count   : 1231
#     Mean    : 5042.92
#     Min     : 52.0
#     Max     : 121951.0
#     Std Dev : 10166.40
#
# 📊 Comments (Numeric)
#     Count   : 1231
#     Mean    : 1842.97
#     Min     : 0.0
#     Max     : 28113.0
#     Std Dev : 2742.73
#
# 📊 Shares (Numeric)
#     Count   : 1231
#     Mean    : 600.95
#     Min     : 0.0
#     Max     : 21291.0
#     Std Dev : 1324.44
#
# 📊 Love (Numeric)
#     Count   : 1231
#     Mean    : 540.80
#     Min     : 0.0
#     Max     : 29561.0
#     Std Dev : 2087.46
#
# 📊 Wow (Numeric)
#     Count   : 1231
#     Mean    : 3.67
#     Min     : 0.0
#     Max     : 56.0
#     Std Dev : 5.92
#
# 📊 Haha (Numeric)
#     Count   : 1231
#     Mean    : 130.40
#     Min     : 0.0
#     Max     : 2551.0
#     Std Dev : 219.68
#
# 📊 Sad (Numeric)
#     Count   : 1231
#     Mean    : 7.58
#     Min     : 0.0
#     Max     : 416.0
#     Std Dev : 28.44
#
# 📊 Angry (Numeric)
#     Count   : 1231
#     Mean    : 22.31
#     Min     : 0.0
#     Max     : 1113.0
#     Std Dev : 70.51
#
# 📊 Care (Numeric)
#     Count   : 1231
#     Mean    : 34.68
#     Min     : 0.0
#     Max     : 1245.0
#     Std Dev : 80.20
#
# 📝 Video Share Status (Categorical)
#     Unique Values : 3
#     Most Frequent : 'owned' (234 times)
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 3
#     Most Frequent : '-' (628 times)
#
# 📊 Post Views (Numeric)
#     Count   : 867
#     Mean    : 5272.20
#     Min     : 0.0
#     Max     : 470237.0
#     Std Dev : 26595.12
#
# 📊 Total Views (Numeric)
#     Count   : 867
#     Mean    : 6726.64
#     Min     : 0.0
#     Max     : 518506.0
#     Std Dev : 34295.24
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 867
#     Mean    : 18.54
#     Min     : 0.0
#     Max     : 8112.0
#     Std Dev : 385.49
#
# 📝 Video Length (Categorical)
#     Unique Values : 106
#     Most Frequent : '00:00:30' (12 times)
#
# 📊 Overperforming Score (Numeric)
#     Count   : 867
#     Mean    : 0.55
#     Min     : -21.27
#     Max     : 44.77
#     Std Dev : 5.19
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.71
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.45
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.57
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.21
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.41
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.10
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.31
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.15
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.09
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.29
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.26
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.24
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.17
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.38
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.15
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.14
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.04
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.05
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.21
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.25
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.43
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.09
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.05
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.14
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.08
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.27
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.25
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.43
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.06
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.19
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.40
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.11
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.31
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.04
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.06
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1231
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 📁 Group: Facebook_Id = 7f5731ac8e6959576e781064b5fa76e059200cdfc3f4e0d7b68bc98792d2cf5b
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : '7f5731ac8e6959576e781064b5fa76e059200cdfc3f4e0d7b68bc98792d2cf5b' (1158 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 1158
#     Most Frequent : '497565dafe2f75548cd6068a32ada78b60de6fec1c4dd70f5a9f9baec94f3f37' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'PERSON' (1068 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (1068 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 1155
#     Most Frequent : '2024-09-30T13:47:21.000Z' (2 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 295
#     Most Frequent : '2023-09-22' (36 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 1138
#     Most Frequent : '18:30:03' (2 times)
#
# 📝 Type (Categorical)
#     Unique Values : 6
#     Most Frequent : 'Photo' (436 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 1158
#     Mean    : 1751.44
#     Min     : 87.0
#     Max     : 33971.0
#     Std Dev : 2230.70
#
# 📊 Likes (Numeric)
#     Count   : 1158
#     Mean    : 797.74
#     Min     : 59.0
#     Max     : 29326.0
#     Std Dev : 1303.99
#
# 📊 Comments (Numeric)
#     Count   : 1158
#     Mean    : 608.75
#     Min     : 4.0
#     Max     : 10573.0
#     Std Dev : 802.02
#
# 📊 Shares (Numeric)
#     Count   : 1158
#     Mean    : 74.64
#     Min     : 4.0
#     Max     : 2516.0
#     Std Dev : 130.53
#
# 📊 Love (Numeric)
#     Count   : 1158
#     Mean    : 131.96
#     Min     : 0.0
#     Max     : 6247.0
#     Std Dev : 286.26
#
# 📊 Wow (Numeric)
#     Count   : 1158
#     Mean    : 2.18
#     Min     : 0.0
#     Max     : 110.0
#     Std Dev : 5.74
#
# 📊 Haha (Numeric)
#     Count   : 1158
#     Mean    : 90.69
#     Min     : 0.0
#     Max     : 2677.0
#     Std Dev : 150.76
#
# 📊 Sad (Numeric)
#     Count   : 1158
#     Mean    : 9.27
#     Min     : 0.0
#     Max     : 4922.0
#     Std Dev : 148.37
#
# 📊 Angry (Numeric)
#     Count   : 1158
#     Mean    : 11.58
#     Min     : 0.0
#     Max     : 1562.0
#     Std Dev : 52.80
#
# 📊 Care (Numeric)
#     Count   : 1158
#     Mean    : 24.63
#     Min     : 0.0
#     Max     : 13706.0
#     Std Dev : 405.19
#
# 📝 Video Share Status (Categorical)
#     Unique Values : 2
#     Most Frequent : 'owned' (344 times)
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 3
#     Most Frequent : '-' (722 times)
#
# 📊 Post Views (Numeric)
#     Count   : 1068
#     Mean    : 2366.88
#     Min     : 0.0
#     Max     : 448192.0
#     Std Dev : 16953.49
#
# 📊 Total Views (Numeric)
#     Count   : 1068
#     Mean    : 2550.38
#     Min     : 0.0
#     Max     : 450313.0
#     Std Dev : 17516.27
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 1068
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📝 Video Length (Categorical)
#     Unique Values : 127
#     Most Frequent : '00:00:30' (14 times)
#
# 📊 Overperforming Score (Numeric)
#     Count   : 1068
#     Mean    : -0.84
#     Min     : -15.01
#     Max     : 13.05
#     Std Dev : 2.62
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.62
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.49
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.44
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.50
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.24
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.42
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.21
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.40
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.15
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.35
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.07
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.26
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.24
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.15
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.13
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.33
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.02
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.14
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.09
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.09
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.29
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.10
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.06
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.24
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.07
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.11
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.12
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.08
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.15
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.36
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.01
#     Min     : 0.0
#     Max     : 1.0
#     Std Dev : 0.12
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1158
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: Facebook_Id = a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813, post_id = 8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813' (1 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'PERSON' (1 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (1 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-04 19:31:16 EDT' (1 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-04' (1 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 1
#     Most Frequent : '19:31:16' (1 times)
#
# 📝 Type (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Photo' (1 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 1
#     Mean    : 261.00
#     Min     : 261.0
#     Max     : 261.0
#     Std Dev : 0.00
#
# 📊 Likes (Numeric)
#     Count   : 1
#     Mean    : 104.00
#     Min     : 104.0
#     Max     : 104.0
#     Std Dev : 0.00
#
# 📊 Comments (Numeric)
#     Count   : 1
#     Mean    : 121.00
#     Min     : 121.0
#     Max     : 121.0
#     Std Dev : 0.00
#
# 📊 Shares (Numeric)
#     Count   : 1
#     Mean    : 8.00
#     Min     : 8.0
#     Max     : 8.0
#     Std Dev : 0.00
#
# 📊 Love (Numeric)
#     Count   : 1
#     Mean    : 12.00
#     Min     : 12.0
#     Max     : 12.0
#     Std Dev : 0.00
#
# 📊 Wow (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Haha (Numeric)
#     Count   : 1
#     Mean    : 14.00
#     Min     : 14.0
#     Max     : 14.0
#     Std Dev : 0.00
#
# 📊 Sad (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Angry (Numeric)
#     Count   : 1
#     Mean    : 2.00
#     Min     : 2.0
#     Max     : 2.0
#     Std Dev : 0.00
#
# 📊 Care (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 1
#     Most Frequent : '-' (1 times)
#
# 📊 Post Views (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Total Views (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Overperforming Score (Numeric)
#     Count   : 1
#     Mean    : 2.29
#     Min     : 2.29
#     Max     : 2.29
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: Facebook_Id = a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813, post_id = 41ec27cecd8af40007a9faf8c3e5c9225bcff0b8d58856563bbc9d59d7dbb6e6
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813' (1 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '41ec27cecd8af40007a9faf8c3e5c9225bcff0b8d58856563bbc9d59d7dbb6e6' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'PERSON' (1 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (1 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-06 20:00:56 EDT' (1 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-06' (1 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 1
#     Most Frequent : '20:00:56' (1 times)
#
# ...
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: Facebook_Id = a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813, post_id = 3e5e0a047865ab02fe0f49c343963239fe7774b63e8ab6001b6ec18f4d37eeac
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813' (1 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 1
#     Most Frequent : '3e5e0a047865ab02fe0f49c343963239fe7774b63e8ab6001b6ec18f4d37eeac' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'PERSON' (1 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (1 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-06 20:01:39 EDT' (1 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-06' (1 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 1
#     Most Frequent : '20:01:39' (1 times)
#
# 📝 Type (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Photo' (1 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 1
#     Mean    : 109.00
#     Min     : 109.0
#     Max     : 109.0
#     Std Dev : 0.00
#
# 📊 Likes (Numeric)
#     Count   : 1
#     Mean    : 34.00
#     Min     : 34.0
#     Max     : 34.0
#     Std Dev : 0.00
#
# 📊 Comments (Numeric)
#     Count   : 1
#     Mean    : 64.00
#     Min     : 64.0
#     Max     : 64.0
#     Std Dev : 0.00
#
# 📊 Shares (Numeric)
#     Count   : 1
#     Mean    : 3.00
#     Min     : 3.0
#     Max     : 3.0
#     Std Dev : 0.00
#
# 📊 Love (Numeric)
#     Count   : 1
#     Mean    : 6.00
#     Min     : 6.0
#     Max     : 6.0
#     Std Dev : 0.00
#
# 📊 Wow (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Haha (Numeric)
#     Count   : 1
#     Mean    : 2.00
#     Min     : 2.0
#     Max     : 2.0
#     Std Dev : 0.00
#
# 📊 Sad (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Angry (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Care (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 1
#     Most Frequent : '-' (1 times)
#
# 📊 Post Views (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Total Views (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 Overperforming Score (Numeric)
#     Count   : 1
#     Mean    : -1.05
#     Min     : -1.05
#     Max     : -1.05
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 1.00
#     Min     : 1.0
#     Max     : 1.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
#
# ============================================================
# 🔗 Group: Facebook_Id = 7ec2cb4abf8effe3d91de57944c56b938b4f33059a6e33dfe23b549cf229989a, post_id = b83adc0e8ac0aedd39f55b72d723729e114a83d41fd48b1b13c7ec782c9a0649
# ============================================================
#
# 📝 Facebook_Id (Categorical)
#     Unique Values : 1
#     Most Frequent : '7ec2cb4abf8effe3d91de57944c56b938b4f33059a6e33dfe23b549cf229989a' (1 times)
#
# 📝 post_id (Categorical)
#     Unique Values : 1
#     Most Frequent : 'b83adc0e8ac0aedd39f55b72d723729e114a83d41fd48b1b13c7ec782c9a0649' (1 times)
#
# 📝 Page Category (Categorical)
#     Unique Values : 1
#     Most Frequent : 'POLITICAL_CANDIDATE' (1 times)
#
# 📝 Page Admin Top Country (Categorical)
#     Unique Values : 1
#     Most Frequent : 'US' (1 times)
#
# 📝 Post Created (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-27 20:13:08 EDT' (1 times)
#
# 📝 Post Created Date (Categorical)
#     Unique Values : 1
#     Most Frequent : '2023-09-27' (1 times)
#
# 📝 Post Created Time (Categorical)
#     Unique Values : 1
#     Most Frequent : '20:13:08' (1 times)
#
# 📝 Type (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Live Video Complete' (1 times)
#
# 📊 Total Interactions (Numeric)
#     Count   : 1
#     Mean    : 268841.00
#     Min     : 268841.0
#     Max     : 268841.0
#     Std Dev : 0.00
#
# 📊 Likes (Numeric)
#     Count   : 1
#     Mean    : 126850.00
#     Min     : 126850.0
#     Max     : 126850.0
#     Std Dev : 0.00
#
# 📊 Comments (Numeric)
#     Count   : 1
#     Mean    : 53191.00
#     Min     : 53191.0
#     Max     : 53191.0
#     Std Dev : 0.00
#
# 📊 Shares (Numeric)
#     Count   : 1
#     Mean    : 20701.00
#     Min     : 20701.0
#     Max     : 20701.0
#     Std Dev : 0.00
#
# 📊 Love (Numeric)
#     Count   : 1
#     Mean    : 62827.00
#     Min     : 62827.0
#     Max     : 62827.0
#     Std Dev : 0.00
#
# 📊 Wow (Numeric)
#     Count   : 1
#     Mean    : 162.00
#     Min     : 162.0
#     Max     : 162.0
#     Std Dev : 0.00
#
# 📊 Haha (Numeric)
#     Count   : 1
#     Mean    : 2241.00
#     Min     : 2241.0
#     Max     : 2241.0
#     Std Dev : 0.00
#
# 📊 Sad (Numeric)
#     Count   : 1
#     Mean    : 128.00
#     Min     : 128.0
#     Max     : 128.0
#     Std Dev : 0.00
#
# 📊 Angry (Numeric)
#     Count   : 1
#     Mean    : 642.00
#     Min     : 642.0
#     Max     : 642.0
#     Std Dev : 0.00
#
# 📊 Care (Numeric)
#     Count   : 1
#     Mean    : 2099.00
#     Min     : 2099.0
#     Max     : 2099.0
#     Std Dev : 0.00
#
# 📝 Video Share Status (Categorical)
#     Unique Values : 1
#     Most Frequent : 'crosspost' (1 times)
#
# 📝 Is Video Owner? (Categorical)
#     Unique Values : 1
#     Most Frequent : 'Yes' (1 times)
#
# 📊 Post Views (Numeric)
#     Count   : 1
#     Mean    : 1332813.00
#     Min     : 1332813.0
#     Max     : 1332813.0
#     Std Dev : 0.00
#
# 📊 Total Views (Numeric)
#     Count   : 1
#     Mean    : 1468579.00
#     Min     : 1468579.0
#     Max     : 1468579.0
#     Std Dev : 0.00
#
# 📊 Total Views For All Crossposts (Numeric)
#     Count   : 1
#     Mean    : 1494352.00
#     Min     : 1494352.0
#     Max     : 1494352.0
#     Std Dev : 0.00
#
# 📝 Video Length (Categorical)
#     Unique Values : 1
#     Most Frequent : '01:08:20' (1 times)
#
# 📊 Overperforming Score (Numeric)
#     Count   : 1
#     Mean    : 2.79
#     Min     : 2.79
#     Max     : 2.79
#     Std Dev : 0.00
#
# 📊 advocacy_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 issue_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 attack_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 image_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 cta_msg_type_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 engagement_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fundraising_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 voting_cta_subtype_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 covid_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 economy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 education_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 environment_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 foreign_policy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 governance_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 health_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 immigration_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 lgbtq_issues_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 military_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 race_and_ethnicity_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 safety_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 social_and_cultural_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 technology_and_privacy_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 womens_issue_topic_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 incivility_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 scam_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 freefair_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
#
# 📊 fraud_illuminating (Numeric)
#     Count   : 1
#     Mean    : 0.00
#     Min     : 0.0
#     Max     : 0.0
#     Std Dev : 0.00
